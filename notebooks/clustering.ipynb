# %%
from typing import List

import random
import numpy as np
import pandas as pd
from conv19_papers import CovidPapers

# sources
biorxiv_medrxiv = 'CORD-19-research-challenge/2020-03-13/biorxiv_medrxiv/biorxiv_medrxiv/'
comm_use_subset = 'CORD-19-research-challenge/2020-03-13/comm_use_subset/comm_use_subset/'

# %%
biomed = CovidPapers(biorxiv_medrxiv)
biomed
# Out:
# <COVID-19(biorxiv_medrxiv, papers=803)>

# %%
def load_papers_with_text(conv: CovidPapers, indices: List[int]):
    """For every paper grab its title and all the available texts."""
    if not isinstance(conv, CovidPapers):
        raise ValueError(
            f'{type(conv)} is not an instance of CovidPapers.')

    batch = []
    papers = conv.load_papers(indices=indices)
    for i, paper in zip(indices, papers):
        title = paper['metadata']['title']
        texts = []
        for key in ('abstract', 'body_text', 'back_matter'):
            sequences = [x['text'] for x in paper[key]]
            for string in sequences:
                if len(string) == 0 and string in texts:
                    continue
                texts.append(string)
        batch.append({'id': i, 'title': title, 'texts': texts})
    return batch

# %%
# lets start with 5 random papers (samples)
samples = list(range(1, biomed.num_papers))
indices = random.sample(samples, k=5)

# each paper is loaded with its title and all texts
batch = load_papers_with_text(biomed, indices)

print(f'number of papers: {len(batch)}')
print(f'keys: {batch[0].keys()}')
# Out:
# number of papers: 5
# keys: dict_keys(['id', 'title', 'texts'])

# %%
# number of text documents per paper index
[(p, len(batch[i]['texts'])) for i, p in enumerate(indices)]
# Out:
# [(520, 29), (726, 43), (476, 18), (637, 15), (753, 34)]

# %%
from david.cosine import SimilarDocuments

max_k = 802
samples = list(range(1, biomed.num_papers))
clusters = random.sample(samples, max_k)
papers = biomed.load_papers(clusters)

titles_cluster = []
for paper in papers:
    title = paper['metadata']['title']
    titles_cluster.append(title)

sd = SimilarDocuments(titles_cluster, ngram=(1, 3))
sd.learn_vocab()

# lets find the most similar titles given one title from the cluster
title_query = titles_cluster[5]
print(title_query)
# Out:
# Clinical Characteristics on 25 Discharged Patients with COVID-19 Virus Returning

# %%
task_1 = [
    'Smoking, pre-existing pulmonary disease',
    'Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities',
    'Neonates and pregnant women',
    'Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences.',]

sd.add_query(task_1, clear_first=True)

# %%
top_k = 40
similar_clusters = list(sd.iter_similar(top_k+1))

similar_papers = []
for c in similar_clusters[1: top_k+1]:
    paper_id, score, title = c['doc_id'], c['sim'], c['text']
    paper_id = paper_id.tolist() # items are instance of numpy.int64
    if paper_id not in similar_papers:
        similar_papers.append(paper_id)
    print('<paper_id={}, score={}>\n * title: {}\n'.format(paper_id, score, title))

sd.clear_queries()
# Out:
# <paper_id=653, score=0.1207>
#  * title: Existing host range mutations constrain further emergence of RNA viruses
#
# <paper_id=537, score=0.0971>
#  * title: TITLE: Pulmonary Metagenomic Sequencing Suggests Missed Infections in Immunocompromised AFFILIATIONS
#
# <paper_id=274, score=0.0946>
#  * title: Title: The impact of persistent bacterial bronchitis on the pulmonary microbiome of
#
# <paper_id=482, score=0.071>
#  * title: Aberrant pathogenic GM-CSF + T cells and inflammatory CD14 + CD16 + monocytes 1 in severe pulmonary syndrome patients of a new coronavirus 2 3
#
# <paper_id=385, score=0.039>
#  * title: Case fatality rate of novel coronavirus disease 2019 in China 1
#
# <paper_id=91, score=0.0382>
#  * title: Acute Myocardial Injury of Patients with Coronavirus Disease 2019
#
# <paper_id=575, score=0.0342>
#  * title: Hypokalemia and Clinical Implications in Patients with Coronavirus Disease 2019 (COVID-19)
#
# <paper_id=513, score=0.0342>
#  * title: Association of Population migration and Coronavirus Disease 2019 epidemic control
#
# <paper_id=206, score=0.0337>
#  * title: The Impact of Host-Based Early Warning on Disease Outbreaks
#
# <paper_id=283, score=0.0334>
#  * title: Title: Risk of disease spillover from dogs to wild carnivores in Kanha Tiger Reserve, India. Running head: Disease spillover from dogs to carnivores
#
# <paper_id=725, score=0.0317>
#  * title: Protective Population Behavior Change in Outbreaks of Emerging Infectious Disease 1 2
#
# <paper_id=247, score=0.0314>
#  * title: Global dynamics of a general vector-borne disease model with two
#
# <paper_id=291, score=0.0313>
#  * title: Immunodepletion with Hypoxemia: A Potential High Risk Subtype of Coronavirus Disease 2019
#
# <paper_id=302, score=0.0305>
#  * title: Estimating the Relative Probability of Direct Transmission between Infectious Disease Patients
#
# <paper_id=761, score=0.0303>
#  * title: Comparison of alternative models of human movement and the spread of disease
#
# <paper_id=232, score=0.0302>
#  * title: Transmission and clinical characteristics of coronavirus disease 2019 in 104 outside-Wuhan patients, China
#
# <paper_id=352, score=0.0302>
#  * title: LY6E impairs coronavirus fusion and confers immune control of viral disease
#
# <paper_id=98, score=0.0301>
#  * title: Reduction and Functional Exhaustion of T Cells in Patients with Coronavirus Disease 2019 (COVID-19)
#
# <paper_id=415, score=0.0299>
#  * title: Title: Modelling the coronavirus disease (COVID-19) outbreak on the Diamond Princess ship using
#
# <paper_id=526, score=0.0298>
#  * title: Clinical and immunologic features in severe and moderate forms of Coronavirus Disease
#
# <paper_id=657, score=0.0296>
#  * title: Evaluating an Upper Respiratory Disease Panel on the Portable MinION Sequencer
#
# <paper_id=115, score=0.0296>
#  * title: Risk factors related to hepatic injury in patients with corona virus disease 2019
#
# <paper_id=697, score=0.0288>
#  * title: Outcome reporting from protocols of clinical trials of Coronavirus Disease 2019 (COVID-19): a review
#
# <paper_id=299, score=0.0287>
#  * title: Facemask shortage and the coronavirus disease (COVID-19) outbreak: Reflection on public health measures
#
# <paper_id=147, score=0.0287>
#  * title: Complete genome characterisation of a novel coronavirus 4 associated with severe human respiratory disease in Wuhan
#
# <paper_id=225, score=0.0283>
#  * title: Lymphopenia predicts disease severity of COVID-19: a descriptive and predictive study Summary Background
#
# <paper_id=218, score=0.0279>
#  * title: Modeling and Prediction of the 2019 Coronavirus Disease Spreading in China Incorporating Human Migration Data
#
# <paper_id=159, score=0.0278>
#  * title: The infant airway microbiome in health and disease impacts later asthma development
#
# <paper_id=37, score=0.0277>
#  * title: Correlation Analysis Between Disease Severity and Inflammation-related Parameters in Patients with COVID-19 Pneumonia
#
# <paper_id=488, score=0.0275>
#  * title: A deep learning algorithm using CT images to screen for Corona Virus Disease (COVID-19)
#
# <paper_id=580, score=0.0272>
#  * title: A quantitative narrative on movement, disease and patch exploitation in nesting agent groups
#
# <paper_id=292, score=0.0271>
#  * title: The molecular basis for Pompe disease 3 revealed by the structure of human acid α-glucosidase 4 5
#
# <paper_id=121, score=0.0269>
#  * title: Sex differences in clinical findings among patients with coronavirus disease 2019 (COVID-19) and severe condition
#
# <paper_id=721, score=0.0264>
#  * title: Hand-hygiene mitigation strategies against global disease spreading through the air transportation network
#
# <paper_id=504, score=0.0264>
#  * title: Transmission of corona virus disease 2019 during the incubation period may lead to a quarantine loophole
#
# <paper_id=748, score=0.0263>
#  * title: A quantitative framework to define the end of an outbreak: application to Ebola Virus Disease "A quantitative framework to define the end of an outbreak: application to Ebola Virus Disease"
#
# <paper_id=343, score=0.0262>
#  * title: Assessing the impact of a symptom-based mass screening 1 and testing intervention during a novel infectious disease
#
# <paper_id=179, score=0.0255>
#  * title: 68 Consecutive patients assessed for COVID-19 infection; experience from a UK regional infectious disease unit
#
# <paper_id=10, score=0.0254>
#  * title: 2019 novel coronavirus disease in hemodialysis (HD) patients: Report from one HD center in Wuhan, China
#
# <paper_id=360, score=0.0253>
#  * title: Early Prediction of Disease Progression in 2019 Novel Coronavirus Pneumonia Patients Outside Wuhan with CT and Clinical Characteristics

# %%
similar_batch = load_papers_with_text(biomed, similar_papers)

# %%
# flatten list of string sequences from all the papers
similar_texts = []
for batch in similar_batch:
    for texts in batch['texts']:
        similar_texts.append(texts)

# %%
similar_texts[0]
# Out:
# 'Nothing to declare.'

# %%
from qaam import QAAM
# Out:
# Using TensorFlow backend.

# %%
qaam = QAAM(.1, top_k=20, metric='cosine', mode='tfidf')

qaam.texts_from_doc(similar_texts)
entities = qaam.common_entities(None, lower=True, lemma=True)
entities[:10]
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=230.0, style=ProgressStyle(description_…
# [('1', 286),
#  ('2', 205),
#  ('3', 169),
#  ('two', 155),
#  ('zika', 146),
#  ('rna', 125),
#  ('first', 124),
#  ('4', 123),
#  ('5', 121),
#  ('wuhan', 119)]

# %%
question = "What are the symptoms in relation to death?"
qaam.answer(question, render=True)
# Out:
# ℹ * Removed 0 tokens from 9680
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 91.82it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 2822.55it/s]
# <h2 style="margin: 0">Question: What are the symptoms in relation to death?</h2><div class="entities" style="line-height: 2.5; direction: ltr">The copyright holder for this preprint (which was not peer-reviewed) is Another critical parameter in infectious disease If the removed data, either the recovered or the recovered plus the death, are reliable, the actual infected people is between 579488 and 941668 by Feb. 17, 2020. <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Every step is a one-way reaction,<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> except the last step from the infected to the removed, as some small amount of the removed could be infected again. The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the . the author/funder, who has granted medRxiv a license to display the preprint in perpetuity. the author/funder, who has granted medRxiv a license to display the preprint in perpetuity.</div>

# %%
question = "What are the pre-existing pulmonary disease risk factors?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 98.12it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 2003.97it/s]
# <h2 style="margin: 0">Question: What are the pre-existing pulmonary disease risk factors?</h2><div class="entities" style="line-height: 2.5; direction: ltr">If the removed data, <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">either the recovered or the recovered plus the death,<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> are reliable, the actual infected people is between 579488 and 941668 by Feb. 17, 2020. Every step is a one-way reaction, except the last step from the infected to the removed, as some small amount of the removed could be infected again. The copyright holder for this preprint (which was not peer-reviewed) is Another critical parameter in infectious disease The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is . The copyright holder for this preprint (which was not peer-reviewed) is .</div>

# %%
question = "Do viral infections make the virus more transmissible?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 77.99it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 5115.00it/s]
# <h2 style="margin: 0">Question: Do viral infections make the virus more transmissible?</h2><div class="entities" style="line-height: 2.5; direction: ltr">The pH of all solutions was adjusted to 7.4 using NaOH and/or KOH, and the osmolarity was adjusted to ~300 mOsm. We found that acute activation of the hM3Dq pathway in microglia increased phagocytosis, increased the production of pro-inflammatory cytokines in the brain, but <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">did not cause overt behavioral changes.<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the .</div>

# %%
question = "What is the economic impact of the virus?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 50.63it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 4275.54it/s]
# <h2 style="margin: 0">Question: What is the economic impact of the virus?</h2><div class="entities" style="line-height: 2.5; direction: ltr">If the removed data, either the recovered or the recovered plus the death, are reliable, the actual infected people is between 579488 and 941668 by Feb. 17, 2020. A sequential chemical reaction process from the susceptible, to the exposed, the infected, and the removed in the end is proposed to describe disease transmissions. In general, our model predicts that the fraction of the infected will peak at certain time, increase with the volume fraction of virus particles, and <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">decrease with temperature.<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> With the parameters obtained from the infected data provided by CCDC, the calculated R 0 is plotted against time in Figure 6 . Disease transmission is difficult to describe, as it is hard to identify the sources of dis- The basic reproduction number of coronavirus is computed to be about 1.5 based on MSIR model and 3.5 based on MSEIR model. Every step is a one-way reaction, except the last step from the infected to the removed, as some small amount of the removed could be infected again.</div>

# %%
question = "What about transmission dynamics of the virus?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 86.65it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 1898.73it/s]
# <h2 style="margin: 0">Question: What about transmission dynamics of the virus?</h2><div class="entities" style="line-height: 2.5; direction: ltr">Among the multiple signals that operate on microglia to modulate their functional state and coordinate their diverse repertoire of functions are neurotransmitters. In contrast, chronic activation of this signaling pathway attenuated the <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">increase in brain cytokine production and sickness behavior<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> triggered by low dose of lipopolysaccharide (LPS) injected peripherally. This dose of LPS was chosen because it is the minimum effective dose to elicit pro-inflammatory cytokine response and sickness behavior in mice Microglia are distributed throughout the CNS and dynamically survey the environment by extending and retracting their highly ramified processes. They account for 5-10% of the total cells in the brain and are necessary for maintaining brain homeostasis (Li and Barres, 2018) . The copyright holder for this preprint (which was not peer-reviewed) is the . The copyright holder for this preprint (which was not peer-reviewed) is the .</div>

# %%
question = "What measures could be effective for control?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 73.06it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 3901.68it/s]
# <h2 style="margin: 0">Question: What measures could be effective for control?</h2><div class="entities" style="line-height: 2.5; direction: ltr">It is increasingly recognized that microglia may be neurotoxic or exert beneficial roles depending on their <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">activation status and release of mediators<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> (Li and Barres, 2018) . To note, most of these studies were done in vitroand microglia have been shown to respond differently when analyzed in vitro or in vivo Animals were housed maximum of four by cage (28x18 author/funder. Microglia are the resident immune cells of the central nervous system. They account for 5-10% of the total cells in the brain and are necessary for maintaining brain homeostasis (Li and Barres, 2018) . The copyright holder for this preprint (which was not peer-reviewed) is the . ) Brains were extracted and postfixed in 4% PFA at 4°C for 24 h. Brains were then cut into 40-µm thick sections using a vibratome (VT1200S, Leica).</div>

# %%
question = "What about Neonates and pregnant women?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 50.01it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 5957.82it/s]
# <h2 style="margin: 0">Question: What about Neonates and pregnant women?</h2><div class="entities" style="line-height: 2.5; direction: ltr">For instance, acetylcholine and nicotine inhibited TNF-α release in response to LPS stimulation Mice were randomly assigned to a treatment group and investigators were blinded during experimental procedures. <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Microglia express numerous types of neurotransmitter receptors<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark> such as those for glutamate, GABA, serotonin, adrenaline and acetylcholine (Kettenmann et al., 2011; Li and Barres, 2018) . It is increasingly recognized that microglia may be neurotoxic or exert beneficial roles depending on their activation status and release of mediators (Li and Barres, 2018) . AB_2535783) and Alexa Fluor 633 goat anti-rabbit (1:1000, ThermoFisher, cat#A-21070 They account for 5-10% of the total cells in the brain and are necessary for maintaining brain homeostasis (Li and Barres, 2018) . bioRxiv preprint cm) and had access to rodent chow (Envigo 7913) and water ad libitum. Microglia are distributed throughout the CNS and dynamically survey the environment by extending and retracting their highly ramified processes.</div>

# %%
question = "Do existing infections make COVID-19 more viral?"
qaam.answer(question, render=True)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 120.31it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 2126.93it/s]
# <h2 style="margin: 0">Question: Do existing infections make COVID-19 more viral?</h2><div class="entities" style="line-height: 2.5; direction: ltr">Unlike our previous work [9] on H7N9 avian influenza which was a retrospective analysis, we are now doing predictive analysis of COVID-19 in an emergency. In general, the quarantine is much more effective than the traffic blockage control. 1000 2000 3000 Number of infections (official) Number of infections (estimated) using both the NCBI RefSeq viral database and the large JGI database. They showed that the reproduction number of infection is 6 .47 Also, we did not author/funder. <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">The empirical parameters on SARS will also work on COVID-19<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANSWER</span></mark>.</div>

# %% [markdown]
# ## Clustering 2
#
# > Clustering using a transformers wrapper API `SentenceTransformers` and scikit-learn's `AgglomerativeClustering`

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering

embedder = SentenceTransformer('bert-base-wikipedia-sections-mean-tokens')
# Out:
# 100%|██████████| 405M/405M [01:35<00:00, 4.25MB/s]

# %%
max_k = 802
samples = list(range(1, biomed.num_papers))
clusters = random.sample(samples, max_k)
papers = biomed.load_papers(clusters)

titles_cluster = []
for paper, cluster in zip(papers, clusters):
    title = paper['metadata']['title']
    titles_cluster.append((title, cluster))
    
titles, clusters = zip(*titles_cluster)

# %%
num_clusters = len(set(titles_cluster))

titles_embedding = embedder.encode(titles)
ac = AgglomerativeClustering(n_clusters=num_clusters)
ac.fit(titles_embedding)
cluster_assignment = ac.labels_

# %%
clustered_titles = [[] for i in range(num_clusters)]

for title_id, cluster_id in enumerate(cluster_assignment):
    title_id = titles_cluster[title_id]
    clustered_titles[cluster_id].append(title_id)
    
for i, cluster in enumerate(clustered_titles):
    print(f'cluster<({i+1})>')
    for row in cluster:
        print(f'paper_id: {row[1]} - {row[0]}')
    print('')
# Out:
# cluster<(1)>
# paper_id: 656 - Title 1 Choanoflagellate transfection illuminates their cell biology and the ancestry of animal septins 2 3 Short Title 4 Robust transfection in choanoflagellates 5 6 Authors 7
#
# cluster<(2)>
# paper_id: 1 - Public Exposure to Live Animals, Behavioural Change, and Support in Containment Measures in response to COVID-19 Outbreak: a population-based cross sectional survey in China
#
# cluster<(3)>
# paper_id: 2 - Classification: Biological Sciences Minor: Microbial Biology Site specific target binding controls RNA cleavage efficiency by the Kaposi's sarcoma-associated herpesvirus endonuclease SOX
#
# cluster<(4)>
# paper_id: 654 - SARS-CoV-2 sensitive to type I interferon pretreatment
#
# cluster<(5)>
# paper_id: 314 - Kinetic Analysis of Bacteriophage Sf6 Binding to Outer Membrane Protein A Using Whole Virions
#
# cluster<(6)>
# paper_id: 732 - Trypsin treatment unlocks barrier for zoonotic coronaviruses infection. Running Title: Trypsin unlocks barrier for zoonotic CoV infection
#
# cluster<(7)>
# paper_id: 504 - When will the battle against novel coronavirus end in Wuhan: a SEIR modeling analysis
#
# cluster<(8)>
# paper_id: 531 - Transferrin binding protein B and Transferrin binding protein A 2 expand the transferrin 1 recognition range of Histophilus somni 2 3 Running title: TbpB and TbpA2 broaden specificity of
#
# cluster<(9)>
# paper_id: 593 - China through a drug-target interaction deep learning model
#
# cluster<(10)>
# paper_id: 400 - Risk factors related to hepatic injury in patients with corona virus disease 2019
#
# cluster<(11)>
# paper_id: 27 - Error patterns in connected speech Stark et al Neural organization of speech production: A lesion-based study of error patterns in connected speech
#
# cluster<(12)>
# paper_id: 703 - TITLE PAGE Title: Machine learning-based CT radiomics model for predicting hospital stay in patients with pneumonia associated with SARS-CoV-2 infection: A multicenter study
#
# cluster<(13)>
# paper_id: 167 - Epitope-based peptide vaccine design and target site characterization against novel coronavirus disease caused by SARS-CoV-2
#
# cluster<(14)>
# paper_id: 202 - Anti-biofilm Activity of Graphene Quantum Dots via Self-Assembly with Bacterial Amyloid Proteins
#
# cluster<(15)>
# paper_id: 222 - Single-cell RNA expression profiling of ACE2, the putative receptor of Wuhan 2019-nCov
#
# cluster<(16)>
# paper_id: 735 - Short Title: Mechanism of HCMV gB vaccine-mediated protection 6 7
#
# cluster<(17)>
# paper_id: 768 - Realtime 2-5A kinetics suggests interferons β and  evade global arrest of translation by RNase L
#
# cluster<(18)>
# paper_id: 361 - Identification of quercetin from fruits to immediately fight Zika
#
# cluster<(19)>
# paper_id: 161 - BAR scaffolds drive membrane fission by crowding disordered domains
#
# cluster<(20)>
# paper_id: 641 - Congruence of location-specific transcriptional programs in intestinal organoids during long-term culture
#
# cluster<(21)>
# paper_id: 258 - Using Digital Surveillance Tools for Near Real-Time Mapping of the Risk of International Infectious Disease Spread: Ebola as a Case Study
#
# cluster<(22)>
# paper_id: 235 - DNA breaks-mediated cost reveals RNase HI as a new target for selectively eliminating antibiotic resistance
#
# cluster<(23)>
# paper_id: 438 - Crystal structure of Nsp15 endoribonuclease NendoU from SARS-CoV-2 Running Title: Structure of Nsp15 from SARS-CoV-2
#
# cluster<(24)>
# paper_id: 183 -
#
# cluster<(25)>
# paper_id: 626 - Evidence for gastrointestinal infection of SARS-CoV-2 1
#
# cluster<(26)>
# paper_id: 226 - Speed and strength of an epidemic intervention
#
# cluster<(27)>
# paper_id: 240 - Ca 2+ ions promote fusion of Middle East Respiratory Syndrome coronavirus with host cells and increase infectivity
#
# cluster<(28)>
# paper_id: 612 - The incubation period of 2019-nCoV from publicly reported confirmed cases: estimation and application
#
# cluster<(29)>
# paper_id: 380 - Evidence for RNA editing in the transcriptome of 2019 Novel Coronavirus
#
# cluster<(30)>
# paper_id: 465 - IFIT3 and IFIT2/3 promote IFIT1-mediated translation inhibition by enhancing binding to non-self RNA
#
# cluster<(31)>
# paper_id: 143 - Prediction of the Epidemic of COVID-19 Based on Quarantined Surveillance in China
#
# cluster<(32)>
# paper_id: 608 - Assessing spread risk of Wuhan novel coronavirus within and beyond China, January-April 2020: a travel network-based modelling study
#
# cluster<(33)>
# paper_id: 134 - The Infectious Bronchitis Virus Coronavirus Envelope Protein Alters Golgi pH to Protect Spike Protein and Promote Release of Infectious Virus
#
# cluster<(34)>
# paper_id: 490 - Vaccination with single plasmid DNA encoding IL-12 and antigens of 2 severe fever with thrombocytopenia syndrome virus elicits complete 3 protection in IFNAR knockout mice Republic of Korea Author summary 57
#
# cluster<(35)>
# paper_id: 225 - Title: A mathematical model for estimating the age-specific transmissibility of a novel 3 coronavirus 4 Running title: Age-specific transmissibility of SARS-CoV-2 5
#
# cluster<(36)>
# paper_id: 100 - Stress-induced phospho-ubiquitin formation causes parkin degradation
#
# cluster<(37)>
# paper_id: 205 - An Effective CTL Peptide Vaccine for Ebola Zaire Based on Survivors' CD8+ Targeting of a Particular Nucleocapsid Protein Epitope with Potential Implications for COVID-19 Vaccine Design
#
# cluster<(38)>
# paper_id: 170 - WeChat, a Chinese social media, may early detect the SARS-CoV-2 outbreak in 2019
#
# cluster<(39)>
# paper_id: 496 - Getting to zero quickly in the 2019-nCov epidemic with vaccines or rapid testing
#
# cluster<(40)>
# paper_id: 761 - Changes in temperature alter susceptibility to a virus following a Short title: Influence of temperature on virus host shifts 4 5
#
# cluster<(41)>
# paper_id: 89 - Enabling large-scale genome editing by reducing DNA nicking
#
# cluster<(42)>
# paper_id: 702 - DNA segment of African Swine Fever Virus 1 first detected in hard ticks from sheep and bovine
#
# cluster<(43)>
# paper_id: 208 - Decoupling the effects of nutrition, age and behavioral caste 2 on honey bee physiology and immunity
#
# cluster<(44)>
# paper_id: 705 - ACE2 expression by colonic epithelial cells is associated with viral infection, immunity and energy metabolism
#
# cluster<(45)>
# paper_id: 404 - Preliminary estimation of the novel coronavirus disease (COVID-19) cases in Iran: a modelling analysis based on overseas cases and air travel data
#
# cluster<(46)>
# paper_id: 251 - Significance of hydrophobic and charged sequence similarities in sodium-bile acid cotransporter and vitamin D-binding protein macrophage activating factor
#
# cluster<(47)>
# paper_id: 410 - Clinical outcomes of 402 patients with COVID-2019 from a single center in Wuhan, China
#
# cluster<(48)>
# paper_id: 701 -
#
# cluster<(49)>
# paper_id: 59 -
#
# cluster<(50)>
# paper_id: 529 - Spread and control of COVID-19 in China and their associations with medical resources 3 4
#
# cluster<(51)>
# paper_id: 706 - Replication of MERS and SARS coronaviruses in bat cells offers insights to their 1 ancestral origins 2 3
#
# cluster<(52)>
# paper_id: 92 - The impact of regular school closure on seasonal influenza epidemics: a data-driven spatial transmission model for Belgium
#
# cluster<(53)>
# paper_id: 602 - Accurate prediction of human essential genes using only nucleotide composition and association information
#
# cluster<(54)>
# paper_id: 204 - Title: Perceptions of the Adult US Population regarding the Novel Coronavirus Outbreak Short title: Perceptions regarding Novel Coronavirus Outbreak
#
# cluster<(55)>
# paper_id: 229 - Clinical Features of COVID-19-Related Liver Damage
#
# cluster<(56)>
# paper_id: 500 - Kallikrein 13: a new player in coronaviral infections. 1 2
#
# cluster<(57)>
# paper_id: 427 - Tracking progress towards malaria elimination in China: estimates of 1 reproduction numbers and their spatiotemporal variation 2 3
#
# cluster<(58)>
# paper_id: 124 - Structure and immune recognition of the porcine epidemic diarrhea virus spike protein
#
# cluster<(59)>
# paper_id: 162 - Prediction of antiviral drugs against African Swine Fever Viruses based on protein-protein interaction analysis
#
# cluster<(60)>
# paper_id: 268 - Title: Probabilistic reconstruction of measles transmission Authors
#
# cluster<(61)>
# paper_id: 18 - Epidemiological and ecological modelling reveal diversity in upper respiratory tract microbial population structures from a cross-sectional community swabbing study Key words Ecology, Epidemiology, Respiratory Infection Running Title Application of epidemiological and ecological modelling to microbial populations Corresponding Author
#
# cluster<(62)>
# paper_id: 748 - Comparative genomics reveals signature regions used to develop a robust and sensitive multiplex TaqMan real-time qPCR assay to detect the genus Dickeya and Dickeya dianthicola
#
# cluster<(63)>
# paper_id: 5 - National Science and Technology Major Project (No. 2017ZX10204401); National Natural Science Foundation of China
#
# cluster<(64)>
# paper_id: 278 - Network-based Drug Repurposing for Human Coronavirus
#
# cluster<(65)>
# paper_id: 788 - Beyond type 1 regulatory T cells: co-expression of LAG3 and CD49b in IL-10-producing T 1 cell lineages 2 3
#
# cluster<(66)>
# paper_id: 327 - TITLE PAGE The SARS-CoV-2 receptor ACE2 expression of maternal-fetal interface and fetal organs by single cell transcriptome study
#
# cluster<(67)>
# paper_id: 664 - Longitudinal characteristics of lymphocyte responses and cytokine profiles in the peripheral blood of SARS-CoV-2 infected patients
#
# cluster<(68)>
# paper_id: 102 - Rapid Detection of 2019 Novel Coronavirus SARS-CoV-2 Using a CRISPR-based 1 DETECTR Lateral Flow Assay 2 3
#
# cluster<(69)>
# paper_id: 510 - Estimating the cure rate and case fatality rate of the ongoing epidemic COVID-19
#
# cluster<(70)>
# paper_id: 771 - A novel defective recombinant porcine enterovirus G virus carrying a 2 porcine torovirus papain-like cysteine protease gene and a putative anti- 3 apoptosis gene in place of viral structural protein genes 4 5 6 Ryo Imai
#
# cluster<(71)>
# paper_id: 257 - A transmissible RNA pathway in honey bees
#
# cluster<(72)>
# paper_id: 711 - Mutations, Recombination and Insertion in the Evolution of 2019-nCoV
#
# cluster<(73)>
# paper_id: 536 - Clinical Characteristics of Patients with Severe Pneumonia Caused by the 2019 Novel Coronavirus in Wuhan, China Title: The clinical characteristics of 2019 novel coronavirus severe pneumonia *Corresponding Author
#
# cluster<(74)>
# paper_id: 270 - In trans variant calling reveals enrichment for compound heterozygous variants in genes involved in neuronal development and growth
#
# cluster<(75)>
# paper_id: 396 - Estimating the daily trend in the size of the COVID-19 infected population in Wuhan
#
# cluster<(76)>
# paper_id: 140 - DeepTracer: Predicting Backbone Atomic Structure from High Resolution Cryo-EM Den- sity Maps of Protein Complexes XXXXXXX Received on XXXXX; revised on XXXXX; accepted on XXXXX
#
# cluster<(77)>
# paper_id: 460 - Molecular Modeling Evaluation of the Binding Effect of Ritonavir, Lopinavir and Darunavir to Severe Acute Respiratory Syndrome Coronavirus 2 Proteases
#
# cluster<(78)>
# paper_id: 445 - Title: Optimizing diagnostic strategy for novel coronavirus pneumonia, a multi-center study in Eastern China Authors (email addresses): Affiliations: Correspondence to
#
# cluster<(79)>
# paper_id: 233 - Messenger RNAs transcribed from yeast linear cytoplasmic plasmids possess unconventional 5' and 3' UTRs and suggest a novel mechanism of translation
#
# cluster<(80)>
# paper_id: 132 - Original Article
#
# cluster<(81)>
# paper_id: 601 - G-quadruplex stabilization in the ions and maltose transporters inhibit Salmonella enterica growth and virulence
#
# cluster<(82)>
# paper_id: 188 - The impact of traffic isolation in Wuhan on the spread of 2019-nCov
#
# cluster<(83)>
# paper_id: 103 - Title: Analyzing Vaccine Trials in Epidemics with Mild and Asymptomatic Infection
#
# cluster<(84)>
# paper_id: 196 - An epidemiological forecast model and software assessing interventions on COVID-19 epidemic in China
#
# cluster<(85)>
# paper_id: 118 - Comparison of alternative models of human movement and the spread of disease
#
# cluster<(86)>
# paper_id: 414 - A novel real-time PCR assay panel for detection of common 1 respiratory pathogens in a convenient, strip-tube array format 2 Running title: Respiratory PCR panel in a strip-tube array format Assistant Professor of Clinical Pathology and Laboratory Medicine Introduction
#
# cluster<(87)>
# paper_id: 405 - Microbiota-independent antiviral protection conferred by aminoglycoside antibiotics 1 2
#
# cluster<(88)>
# paper_id: 15 - Epidemiological characteristics of 1212 COVID-19 patients in Henan, China. medRxiv
#
# cluster<(89)>
# paper_id: 521 - Generating genomic platforms to study Candida albicans pathogenesis
#
# cluster<(90)>
# paper_id: 129 - 50-valent inactivated rhinovirus vaccine is broadly immunogenic in rhesus macaques
#
# cluster<(91)>
# paper_id: 279 - Title: Close contacts and household transmission of SARS-CoV-2 in China: a content analysis based on local Heath Commissions' public disclosures
#
# cluster<(92)>
# paper_id: 734 - Clinical Characteristics of 24 Asymptomatic Infections with COVID-19 Screened among Close Contacts in Nanjing, China School of Public Health (
#
# cluster<(93)>
# paper_id: 720 - In-silico immune cell deconvolution of the airway proteomes of infants with pneumonia reveals a link between reduced airway eosinophils and an increased risk of mortality
#
# cluster<(94)>
# paper_id: 778 - Protective Population Behavior Change in Outbreaks of Emerging Infectious Disease 1 2
#
# cluster<(95)>
# paper_id: 248 - Mono-ADP-ribosylation by ARTD10 restricts Chikungunya virus replication by interfering with the proteolytic activity of nsP2 2 3 4
#
# cluster<(96)>
# paper_id: 605 -
#
# cluster<(97)>
# paper_id: 560 - Establishment of primary transgenic human airway 1 epithelial cell cultures to study respiratory virus - 2 host interactions 3
#
# cluster<(98)>
# paper_id: 332 - Title: The impact of persistent bacterial bronchitis on the pulmonary microbiome of
#
# cluster<(99)>
# paper_id: 214 - Emotional responses and coping strategies of nurses and nursing college students during COVID-19 outbreak
#
# cluster<(100)>
# paper_id: 659 - How domain growth is implemented determines the long term behaviour of a cell population through its effect on spatial correlations
#
# cluster<(101)>
# paper_id: 352 - Modeling and Prediction of the 2019 Coronavirus Disease Spreading in China Incorporating Human Migration Data
#
# cluster<(102)>
# paper_id: 366 - Title: HOPS-dependent endosomal fusion required for efficient cytosolic delivery of therapeutic peptides and small proteins
#
# cluster<(103)>
# paper_id: 115 - Estimation of the final size of the COVID-19 epidemic
#
# cluster<(104)>
# paper_id: 621 - Prediction of criticality in patients with severe Covid-19 infection using three clinical features: a machine learning-based prognostic model with clinical data in Wuhan
#
# cluster<(105)>
# paper_id: 376 - Crystal structure of the giant panda MHC class I complex: first insights into the viral 1 peptide presentation profile in the bear family 2
#
# cluster<(106)>
# paper_id: 488 - A binning tool to reconstruct viral haplotypes from assembled contigs
#
# cluster<(107)>
# paper_id: 698 - Structural modeling of 2019-novel coronavirus (nCoV) spike protein reveals a proteolytically- sensitive activation loop as a distinguishing feature compared to SARS-CoV and related SARS- like coronaviruses
#
# cluster<(108)>
# paper_id: 434 - An interaction network of RNA-binding proteins involved in Drosophila oogenesis Running title: Interactome of RNA Binding Proteins from Drosophila ovaries
#
# cluster<(109)>
# paper_id: 179 - Identification of a Nidovirales Orf1a N7-guanine cap Methyltransferase signature- sequence as a genetic marker of large genome Tobaniviridae Running title: RNA cap N7-guanine Methyltransferase in Tobaniviridae Orf1a
#
# cluster<(110)>
# paper_id: 52 - Nucleotide Analogues as Inhibitors of Viral Polymerases
#
# cluster<(111)>
# paper_id: 371 - HCAtk and pyHCA: A Toolkit and Python API for the Hydrophobic Cluster Analysis of Protein Sequences
#
# cluster<(112)>
# paper_id: 169 - Understanding the present status and forecasting of COVID-19 in Wuhan
#
# cluster<(113)>
# paper_id: 22 - A single locus underlies variation in Caenorhabditis elegans chemotherapeutic responses
#
# cluster<(114)>
# paper_id: 677 - Complex dynamics in an SIS epidemic model induced by nonlinear incidence
#
# cluster<(115)>
# paper_id: 505 - From Isolation to Coordination: How Can Telemedicine Help Combat the COVID-19 Outbreak?
#
# cluster<(116)>
# paper_id: 13 - Epidemiological parameter review and comparative dynamics of influenza, respiratory syncytial virus, rhinovirus, human coronavirus, and adenovirus
#
# cluster<(117)>
# paper_id: 802 - Analysis of early renal injury in COVID-19 and diagnostic value of multi-index combined detection
#
# cluster<(118)>
# paper_id: 61 - Clinical characteristics of 2019 novel coronavirus infection in China
#
# cluster<(119)>
# paper_id: 165 - Epidemic analysis of COVID-19 in China by dynamical modeling
#
# cluster<(120)>
# paper_id: 274 - Estimating the Efficacy of Quarantine and Traffic Blockage for the Epidemic Caused by 2019-nCoV (COVID-19)：A Simulation Analysis
#
# cluster<(121)>
# paper_id: 475 - Loss of IKK subunits limits NF-κB signaling in reovirus infected cells 4 5
#
# cluster<(122)>
# paper_id: 219 - Modulation of metabolic functions through Cas13d-mediated gene knockdown in liver
#
# cluster<(123)>
# paper_id: 142 - Substrate specificity profiling of SARS-CoV-2 M pro protease provides basis for anti-COVID-19 drug design
#
# cluster<(124)>
# paper_id: 387 - Metagenomic Nanopore sequencing of influenza virus 1 direct from clinical respiratory samples 2 3
#
# cluster<(125)>
# paper_id: 780 - performed data analysis
#
# cluster<(126)>
# paper_id: 757 - Cryo-EM structures of HKU2 and SADS-CoV spike 1 glycoproteins and insights into coronavirus evolution 2 3 4
#
# cluster<(127)>
# paper_id: 338 - A deep learning algorithm using CT images to screen for Corona Virus Disease (COVID-19)
#
# cluster<(128)>
# paper_id: 449 - Running title: The transcriptional and translational landscape of equine torovirus 1
#
# cluster<(129)>
# paper_id: 244 - ACE2 and the cellular protease TMPRSS2 for entry into target cells 2 3
#
# cluster<(130)>
# paper_id: 305 - Spatial epidemiology of networked metapopulation: An overview
#
# cluster<(131)>
# paper_id: 653 - Chronic hM3Dq signaling in microglia ameliorates neuroinflammation in male mice Abbreviated title: hM3Dq signaling in microglia
#
# cluster<(132)>
# paper_id: 4 - Neutrophil-to-Lymphocyte Ratio Predicts Severe Illness Patients with 2019 Novel Coronavirus in the Early Stage
#
# cluster<(133)>
# paper_id: 128 - Dysregulation of Long Non-coding RNA (lncRNA) Genes and Predicted lncRNA-protein Interactions during Zika Virus Infection
#
# cluster<(134)>
# paper_id: 168 - Multiplex logic processing isothermal diagnostic assays for an evolving virus
#
# cluster<(135)>
# paper_id: 191 - The within-host viral kinetics of SARS-CoV-2
#
# cluster<(136)>
# paper_id: 663 - Contacts in context: large-scale setting-specific social mixing matrices from the BBC Pandemic project
#
# cluster<(137)>
# paper_id: 385 - Epidemic doubling time of the COVID-19 epidemic by Chinese province 1
#
# cluster<(138)>
# paper_id: 203 - Large-scale Lassa fever outbreaks in Nigeria: quantifying the association between disease reproduction number and local rainfall
#
# cluster<(139)>
# paper_id: 330 - Identification of the relative timing of infectiousness 1 and symptom onset for outbreak control 2
#
# cluster<(140)>
# paper_id: 281 - The effect of variant interference on de novo assembly for viral deep sequencing
#
# cluster<(141)>
# paper_id: 351 - Mouse hepatitis virus nsp14 exoribonuclease activity is required for
#
# cluster<(142)>
# paper_id: 403 - Human, Nonhuman Primate, and Bat Cells Are Broadly Susceptible 1 to Tibrovirus Particle Cell Entry 2 3 Running Title: 3/5 words
#
# cluster<(143)>
# paper_id: 691 - Title 4 Spike-based phylogenetically defined clades within the Alphacoronavirus 1 species 5 6 Authors 7
#
# cluster<(144)>
# paper_id: 511 - Assessing the impact of reduced travel on exportation dynamics of novel coronavirus infection (COVID-19)
#
# cluster<(145)>
# paper_id: 17 - Correlation Analysis Between Disease Severity and Inflammation-related Parameters in Patients with COVID-19 Pneumonia
#
# cluster<(146)>
# paper_id: 726 - CORONAVIRUS IN PREGNANCY AND DELIVERY: RAPID REVIEW AND EXPERT CONSENSUS
#
# cluster<(147)>
# paper_id: 62 - Vulnerabilities in coronavirus glycan shields despite extensive glycosylation
#
# cluster<(148)>
# paper_id: 600 - Title: The incubation period of 2019-nCoV infections among travellers from Wuhan, China
#
# cluster<(149)>
# paper_id: 297 - Complete genome characterisation of a novel coronavirus 4 associated with severe human respiratory disease in Wuhan
#
# cluster<(150)>
# paper_id: 770 - A new phylogenetic protocol: Dealing with model misspecification and confirmation bias in molecular phylogenetics
#
# cluster<(151)>
# paper_id: 166 - 68 Consecutive patients assessed for COVID-19 infection; experience from a UK regional infectious disease unit
#
# cluster<(152)>
# paper_id: 301 - Lessons learnt from 288 COVID-19 international cases: importations over time, effect of interventions, underdetection of imported cases
#
# cluster<(153)>
# paper_id: 75 - The impact of social distancing and epicenter lockdown on the COVID-19 epidemic in mainland China: A data-driven SEIQR model study
#
# cluster<(154)>
# paper_id: 137 - p53 is not necessary for DUX4 pathology
#
# cluster<(155)>
# paper_id: 300 - MYCOPLASMA FAUCIUM AND BREAST CANCER
#
# cluster<(156)>
# paper_id: 480 - Transmission of corona virus disease 2019 during the incubation period may lead to a quarantine loophole
#
# cluster<(157)>
# paper_id: 293 - Assessing Topographic Structural Connectivity of the Human Basal Ganglia and Thalamus
#
# cluster<(158)>
# paper_id: 106 - Transmission potential of COVID-19 in Iran 1
#
# cluster<(159)>
# paper_id: 535 - Transmission Dynamics of 2019-nCoV in Malaysia
#
# cluster<(160)>
# paper_id: 497 - Human Kidney is a Target for Novel Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV-2) Infection Running title: SARS-CoV-2 infects human kidney
#
# cluster<(161)>
# paper_id: 390 - Title page • Title A combinatorial biomolecular strategy to identify peptides for improved transport across the sputum of cystic fibrosis patients and the underlying epithelia • Author names and affiliations
#
# cluster<(162)>
# paper_id: 667 - Time-varying transmission dynamics of Novel Coronavirus Pneumonia in China At a Glance Commentary Scientific Knowledge on the Subject: Since
#
# cluster<(163)>
# paper_id: 689 - Lung epithelial cells have virus-specific and shared gene expression responses 1 to infection by diverse respiratory viruses 2 3
#
# cluster<(164)>
# paper_id: 64 - Bulk and single-cell transcriptomics identify tobacco-use disparity in lung gene expression of ACE2, the receptor of 2019-nCov
#
# cluster<(165)>
# paper_id: 267 - Gender differences in patients with COVID-19: Focus on severity and mortality
#
# cluster<(166)>
# paper_id: 391 - Deconvoluting Virome-Wide Antiviral Antibody Profiling Data
#
# cluster<(167)>
# paper_id: 360 - Alphavirus nsP3 ADP-ribosylhydrolase Activity Disrupts Stress Granule Formation
#
# cluster<(168)>
# paper_id: 455 - TITLE: Pulmonary Metagenomic Sequencing Suggests Missed Infections in Immunocompromised AFFILIATIONS
#
# cluster<(169)>
# paper_id: 47 - Genome-wide Prediction of microRNAs in Zika virus Genomes Reveals Possible Interactions with Human Genes Involved in the Nervous System Development
#
# cluster<(170)>
# paper_id: 777 - Amplicon based MinION sequencing of SARS-CoV-2 and metagenomic characterisation of nasopharyngeal swabs from patients with COVID-19
#
# cluster<(171)>
# paper_id: 101 - The host antiviral ribonuclease L protein supports Zika virus replication 3 factory formation to enhance infectious virus production 4 5
#
# cluster<(172)>
# paper_id: 546 - Analytical sensibility and specificity of two RT-qPCR protocols for SARS-CoV-2 detection performed in an automated workflow
#
# cluster<(173)>
# paper_id: 172 - Neuronal CCL2 expression drives inflammatory monocyte infiltration into the brain during acute virus infection
#
# cluster<(174)>
# paper_id: 717 - Characteristics of lymphocyte subsets and cytokines in peripheral blood of 123 hospitalized 2 patients with 2019 novel coronavirus pneumonia (NCP) 3
#
# cluster<(175)>
# paper_id: 408 - Evolution and variation of 2019-novel coronavirus
#
# cluster<(176)>
# paper_id: 709 - COVID-19 Epidemic Outside China: 34 Founders and Exponential Growth
#
# cluster<(177)>
# paper_id: 263 - Title: Metagenomic Sequencing Detects Respiratory Pathogens in Hematopoietic Cellular Transplant Patients Running Title: mNGS Detects Respiratory Pathogens in HCT Patients
#
# cluster<(178)>
# paper_id: 83 - Gut microbiota structure differs between honey
#
# cluster<(179)>
# paper_id: 280 - Long non-coding RNA Gm15441 attenuates hepatic inflammasome activation in response to metabolic stress
#
# cluster<(180)>
# paper_id: 738 - X-ray Structure of Main Protease of the Novel Coronavirus SARS-CoV-2 Enables Design of a-Ketoamide Inhibitors
#
# cluster<(181)>
# paper_id: 81 - Influence of different glycoproteins and of the virion core on SERINC5 antiviral activity
#
# cluster<(182)>
# paper_id: 201 - A mathematical model for simulating the transmission of Wuhan novel Coronavirus
#
# cluster<(183)>
# paper_id: 765 - Clinical and Laboratory Profiles of 75 Hospitalized Patients with Novel
#
# cluster<(184)>
# paper_id: 566 - TLR5 participates in the TLR4 receptor complex and biases towards MyD88-dependent 1 signaling in environmental lung injury 2
#
# cluster<(185)>
# paper_id: 157 - Real-time, MinION-based, amplicon sequencing for lineage typing of infectious bronchitis virus from upper respiratory samples
#
# cluster<(186)>
# paper_id: 78 - Clinical characteristics of 50466 patients with 2019-nCoV infection
#
# cluster<(187)>
# paper_id: 639 - Modeling the Comparative Impact of Individual Quarantine vs. Active Monitoring of Contacts for the Mitigation of COVID-19
#
# cluster<(188)>
# paper_id: 131 - Analysis of epidemiological characteristics of coronavirus 2019 infection and preventive measures in Shenzhen China-a heavy population city
#
# cluster<(189)>
# paper_id: 310 - Modelling the epidemic trend of the 2019 novel coronavirus outbreak in China
#
# cluster<(190)>
# paper_id: 415 - Infectious bronchitis virus attaches to lipid rafts and enters cells via clathrin mediated endocytosis
#
# cluster<(191)>
# paper_id: 749 - Estimation of the epidemic properties of the 2019 novel coronavirus: A mathematical modeling study
#
# cluster<(192)>
# paper_id: 249 - Clinical Characteristics on 25 Discharged Patients with COVID-19 Virus Returning
#
# cluster<(193)>
# paper_id: 690 -
#
# cluster<(194)>
# paper_id: 76 - Etiology of fever in Ugandan children: identification of microbial pathogens using 1 metagenomic next-generation sequencing and IDseq, a platform for unbiased metagenomic 2 analysis 3 4
#
# cluster<(195)>
# paper_id: 644 - SEIR Transmission dynamics model of 2019 nCoV coronavirus with considering the weak infectious ability and changes in latency duration
#
# cluster<(196)>
# paper_id: 783 - Validation and automation of a high-throughput multi-targeted method for semi-quantification of 2 endogenous metabolites from different biological matrices using tandem mass spectrometry 4
#
# cluster<(197)>
# paper_id: 506 - Freshwater monitoring by nanopore sequencing
#
# cluster<(198)>
# paper_id: 633 - Electroporated recombinant proteins as tools for in vivo functional
#
# cluster<(199)>
# paper_id: 335 -
#
# cluster<(200)>
# paper_id: 130 - The genome of the crustacean Parhyale hawaiensis: a model for animal 2 development, regeneration, immunity 3 and lignocellulose digestion 4 United Kingdom Molecular and Cell Biology
#
# cluster<(201)>
# paper_id: 406 - Glycosyltransferases promote development and prevent promiscuous cell
#
# cluster<(202)>
# paper_id: 750 - Evaluating the accuracy of different respiratory specimens in the laboratory diagnosis and monitoring the viral shedding of 2019-nCoV infections
#
# cluster<(203)>
# paper_id: 48 - Alterations in sialic-acid O-acetylation glycoforms during murine erythrocyte development
#
# cluster<(204)>
# paper_id: 728 - Estimation of incubation period distribution of COVID-19 using disease onset forward time: a novel cross-sectional and forward follow-up study
#
# cluster<(205)>
# paper_id: 144 - Rapid Molecular Detection of SARS-CoV-2 (COVID-19) Virus RNA Using Colorimetric LAMP
#
# cluster<(206)>
# paper_id: 147 - Evolved sequence features within the intrinsically disordered tail influence FtsZ assembly and bacterial cell division
#
# cluster<(207)>
# paper_id: 632 - Open-source analytics tools for studying the COVID-19 coronavirus outbreak
#
# cluster<(208)>
# paper_id: 412 - The infection evidence of SARS-COV-2 in ocular surface： a single-center cross-sectional study Funding Sources
#
# cluster<(209)>
# paper_id: 574 - Quantifying bias of COVID-19 prevalence and severity estimates in Wuhan, China that depend on reported cases in international travelers
#
# cluster<(210)>
# paper_id: 755 - Long-Term Persistence of IgG Antibodies in SARS-CoV Infected Healthcare Workers 2 3
#
# cluster<(211)>
# paper_id: 77 - Clearing the FoG: Antifungal tolerance is a subpopulation effect that is distinct from 3 resistance and is associated with persistent candidemia 4 5
#
# cluster<(212)>
# paper_id: 544 - Inferring generation-interval distributions from contact-tracing 2 data
#
# cluster<(213)>
# paper_id: 9 - ADJUSTED AGE-SPECIFIC CASE FATALITY RATIO DURING THE COVID-19 EPIDEMIC IN HUBEI, CHINA
#
# cluster<(214)>
# paper_id: 184 - Mortality of COVID-19 is Associated with Cellular Immune Function Compared to Immune Function in Chinese Han Population
#
# cluster<(215)>
# paper_id: 585 - Global dynamics of a general vector-borne disease model with two
#
# cluster<(216)>
# paper_id: 370 - A Multiscale and Comparative Model for Receptor Binding of 2019 Novel Coronavirus and the Implication of its Life Cycle in Host Cells
#
# cluster<(217)>
# paper_id: 6 - The Essential Facts of Wuhan Novel Coronavirus Outbreak in China and Epitope-based Vaccine Designing against COVID-19
#
# cluster<(218)>
# paper_id: 110 - CORRELATION OF MRNA DELIVERY TIMING AND PROTEIN EXPRESSION IN LIPID-BASED TRANSFECTION
#
# cluster<(219)>
# paper_id: 756 - Demonstration of four entities of appendicitis in China through studying cluster/outbreak
#
# cluster<(220)>
# paper_id: 413 - PLANT-Dx: A Molecular Diagnostic for Point of Use Detection of Plant Pathogens
#
# cluster<(221)>
# paper_id: 754 - Biological Evaluation of Molecules of the azaBINOL Class as Antiviral Agents: 1 Specific Inhibition of HIV-1 RNase H Activity by 7-Isopropoxy-8-(naphth-1-yl)quinoline 2 3 4 5
#
# cluster<(222)>
# paper_id: 772 - tailfindr: Alignment-free poly(A) length measurement for Oxford Nanopore RNA and DNA sequencing
#
# cluster<(223)>
# paper_id: 561 - Association of radiologic findings with mortality of patients infected with 2019 novel coronavirus in Wuhan, China
#
# cluster<(224)>
# paper_id: 512 - Evolutionary origins of epidemic potential among human RNA viruses
#
# cluster<(225)>
# paper_id: 651 - Therapeutic Drugs Targeting 2019-nCoV Main Protease by High-Throughput Screening
#
# cluster<(226)>
# paper_id: 766 - Prognostic value of NT-proBNP in patients with severe COVID-19
#
# cluster<(227)>
# paper_id: 470 - Spatially Explicit Modeling of 2019-nCoV Epidemic Trend Based on Mobile Phone Data in Mainland China
#
# cluster<(228)>
# paper_id: 665 - Large-scale analysis of redox-sensitive conditionally disordered protein regions reveal their widespread nature and key roles in high-level eukaryotic processes
#
# cluster<(229)>
# paper_id: 34 - Effect of non-pharmaceutical interventions for containing the COVID-19 outbreak: an observational and modelling study
#
# cluster<(230)>
# paper_id: 573 - ZIKA VIRUS INFECTION AT DIFFERENT PREGNANCY STAGES: ANATOMOPATHOLOGICAL FINDINGS, TARGET CELLS AND VIRAL PERSISTENCE IN PLACENTAL TISSUES Running title ZIKA VIRUS INFECTION IN HUMAN PLACENTAS List of authors
#
# cluster<(231)>
# paper_id: 773 - No more business as usual: agile and effective responses to emerging pathogen threats require open data and open analytics Authors and contributions
#
# cluster<(232)>
# paper_id: 769 - Programmable low-cost DNA-based platform for viral RNA detection
#
# cluster<(233)>
# paper_id: 23 - A practical generation interval-based approach to inferring the strength of epidemics from their speed Keywords Infectious disease modeling; Generation interval; basic reproductive number 1
#
# cluster<(234)>
# paper_id: 146 - Evidence for influenza B virus hemagglutinin adaptation to the human host: high cleavability, acid-stability and 2 preference for cool temperature Running title: Adaptation of influenza B virus HA to human airways 5 6
#
# cluster<(235)>
# paper_id: 153 - SKEMPI 2.0: An updated benchmark of changes in protein-protein binding energy, kinetics and thermodynamics upon mutation
#
# cluster<(236)>
# paper_id: 672 - Spreading predictability in complex networks
#
# cluster<(237)>
# paper_id: 49 - Viral fitness predicts the magnitude and direction of perturbations in the infected host transcriptome
#
# cluster<(238)>
# paper_id: 483 - Stochastic challenges to interrupting helminth transmission
#
# cluster<(239)>
# paper_id: 19 - Title: Novel tetraplex qPCR assays for simultaneous detection and identification of Xylella fastidiosa subspecies in plant tissues
#
# cluster<(240)>
# paper_id: 42 - Development and Evaluation of A CRISPR-based Diagnostic For 2019-novel Coronavirus
#
# cluster<(241)>
# paper_id: 543 - Distinct spread of DNA and RNA viruses among mammals amid prominent role of domestic species
#
# cluster<(242)>
# paper_id: 121 - Anti-microbial immunity is impaired in COPD patients with frequent exacerbations
#
# cluster<(243)>
# paper_id: 429 - Quantifying the roles of vomiting, diarrhea, and residents vs. staff in
#
# cluster<(244)>
# paper_id: 85 - Deep sequencing of primary human lung epithelial cells challenged with H5N1 influenza virus reveals 1 a proviral role for CEACAM1 2 3
#
# cluster<(245)>
# paper_id: 784 - The role of institutional trust in preventive and treatment-seeking behaviors during the 2019 novel coronavirus (2019-nCoV) outbreak among residents in Hubei, China
#
# cluster<(246)>
# paper_id: 625 - Community responses during the early phase of the COVID-19 epidemic in Hong Kong: risk 1 perception, information exposure and preventive measures 2 3 Background: Community responses are important for outbreak management during the early phase
#
# cluster<(247)>
# paper_id: 495 - Direct Measurement of Rates of Asymptomatic Infection and Clinical Care- Seeking for Seasonal Coronavirus
#
# cluster<(248)>
# paper_id: 223 - Comparative analysis of primer-probe sets for the laboratory confirmation of SARS-CoV-2
#
# cluster<(249)>
# paper_id: 113 - Enhanced replication of mouse adenovirus type 1 following virus-induced degradation of protein 3 kinase R (PKR) 4 5 Running Title: MAV-1 degrades PKR during infection 6 7
#
# cluster<(250)>
# paper_id: 256 - A Note on NCP Diagnosis Number Prediction Model
#
# cluster<(251)>
# paper_id: 421 - A simple magnetic nanoparticles-based viral RNA extraction method for efficient detection of SARS-CoV-2
#
# cluster<(252)>
# paper_id: 736 - Pangolin homology associated with 2019-nCoV
#
# cluster<(253)>
# paper_id: 71 - Novel ionophores active against La Crosse virus identified through rapid 1 antiviral screening 2 3
#
# cluster<(254)>
# paper_id: 80 - Structure of dimeric full-length human ACE2 in complex with B 0 AT1
#
# cluster<(255)>
# paper_id: 192 - Title: A descriptive study of the impact of diseases control and prevention on the epidemics 1 dynamics and clinical features of SARS-CoV-2 outbreak in Shanghai, lessons learned for
#
# cluster<(256)>
# paper_id: 433 - Estimating number of global importations of COVID-19 from Wuhan, risk of transmission outside mainland China and COVID-19 introduction index between countries outside mainland China
#
# cluster<(257)>
# paper_id: 794 - Host shifts result in parallel genetic changes when viruses evolve in closely related species 1 2
#
# cluster<(258)>
# paper_id: 206 - Title: Incorporating Human Movement Data to Improve Epidemiological Estimates for 2019-nCoV
#
# cluster<(259)>
# paper_id: 764 - Rapid Therapeutic Recommendations in the Context of a Global Public Health Crisis using Translational Bioinformatics Approaches: A proof-of-concept study using Nipah Virus Infection
#
# cluster<(260)>
# paper_id: 502 - Prediction of receptorome for human-infecting virome
#
# cluster<(261)>
# paper_id: 424 - A method for RNA structure prediction shows evidence for structure in lncRNAs
#
# cluster<(262)>
# paper_id: 199 - Title page The landscape of lung bronchoalveolar immune cells in COVID-19 revealed by single-cell RNA sequencing
#
# cluster<(263)>
# paper_id: 409 - Epidemiology and Transmission of COVID-19 in Shenzhen China: Analysis of 391 cases and 1,286 of their close contacts
#
# cluster<(264)>
# paper_id: 245 - A model simulation study on effects of intervention measures in Wuhan COVID-19 epidemic
#
# cluster<(265)>
# paper_id: 718 - Similar ratios of introns to intergenic sequence across animal 1 genomes
#
# cluster<(266)>
# paper_id: 542 - Quantitative Delineation of Herpesviruses in Bats for use in Ecological Studies
#
# cluster<(267)>
# paper_id: 43 - Proofreading-deficient coronaviruses adapt over long-term passage for increased fidelity and 1 fitness without reversion of exoribonuclease-inactivating mutations 2 3 4
#
# cluster<(268)>
# paper_id: 398 - Appealing for Efficient, Well Organized Clinical Trials on COVID-19
#
# cluster<(269)>
# paper_id: 354 - Virome heterogeneity and connectivity in waterfowl and shorebird Running Title: Viromes of waterbird communities 4 5
#
# cluster<(270)>
# paper_id: 439 - PGC-1α coordinates with Bcl-2 to control cell cycle in U251 Running title: PGC-1α regulates cell cycle 4 Summary statement: PGC-1α coordinate with Bcl-2 delay cell cycle progression to
#
# cluster<(271)>
# paper_id: 727 - A simple laboratory parameter facilitates early identification of COVID-19 patients
#
# cluster<(272)>
# paper_id: 54 - Existing host range mutations constrain further emergence of RNA viruses
#
# cluster<(273)>
# paper_id: 136 - TWIRLS, an automated topic-wise inference method based on massive literature, suggests a possible mechanism via ACE2 for the pathological changes in the human host after coronavirus infection
#
# cluster<(274)>
# paper_id: 377 - Clinical features and outcomes of 221 patients with COVID-19 in Wuhan, China
#
# cluster<(275)>
# paper_id: 631 - The guanine nucleotide exchange factor GBF1 participates in rotavirus
#
# cluster<(276)>
# paper_id: 674 - Interleukin-33 promotes type 1 cytokine expression via p38 MAPK in human natural killer cells
#
# cluster<(277)>
# paper_id: 563 - Highland of COVID-19 outside Hubei: epidemic characteristics, control and projections of Wenzhou, China
#
# cluster<(278)>
# paper_id: 741 - Evaluating new evidence in the early dynamics of the novel coronavirus COVID-19 outbreak in Wuhan, China with real time domestic traffic and potential asymptomatic transmissions
#
# cluster<(279)>
# paper_id: 148 - A planarian nidovirus expands the limits of RNA genome size Significance Statement
#
# cluster<(280)>
# paper_id: 758 - Fractal kinetics of COVID-19 pandemic (with update 3/1/20)
#
# cluster<(281)>
# paper_id: 217 - Clinical Data on Hospital Environmental Hygiene Monitoring and Medical Staff Protection during the Coronavirus Disease 2019 2 Outbreak
#
# cluster<(282)>
# paper_id: 109 - Optimising Renewal Models for Real-Time Epidemic Prediction and Estimation
#
# cluster<(283)>
# paper_id: 21 - Potent neutralization of 2019 novel coronavirus by recombinant ACE2-Ig
#
# cluster<(284)>
# paper_id: 322 - Complemented palindrome small RNAs first discovered from SARS coronavirus
#
# cluster<(285)>
# paper_id: 8 - C19ORF66 broadly escapes viral-induced endonuclease cleavage and restricts Kaposi's 1
#
# cluster<(286)>
# paper_id: 176 - The infant airway microbiome in health and disease impacts later asthma development
#
# cluster<(287)>
# paper_id: 193 - Clinical and immunologic features in severe and moderate forms of Coronavirus Disease
#
# cluster<(288)>
# paper_id: 486 - Spike protein binding prediction with neutralizing antibodies of SARS-CoV-2 1 2
#
# cluster<(289)>
# paper_id: 613 - The network structure and eco-evolutionary dynamics of CRISPR-induced immune diversification
#
# cluster<(290)>
# paper_id: 436 - Application and optimization of RT-PCR in diagnosis of SARS-CoV-2 infection
#
# cluster<(291)>
# paper_id: 364 - 2019 novel coronavirus disease in hemodialysis (HD) patients: Report from one HD center in Wuhan, China
#
# cluster<(292)>
# paper_id: 737 - More than efficacy revealed by single-cell analysis of antiviral therapeutics
#
# cluster<(293)>
# paper_id: 733 - Study of the mental health status of medical personnel dealing with new coronavirus pneumonia
#
# cluster<(294)>
# paper_id: 74 - Title: 2 The Role of Interleukin-1 cytokine family (IL-1β, IL-37) and interleukin-12 cytokine 3 family (IL-12, IL-35) in eumycetoma infection pathogenesis. Authors 7 Corresponding Author
#
# cluster<(295)>
# paper_id: 678 - Multimerization of HIV-1 integrase hinges on conserved SH3-docking platforms
#
# cluster<(296)>
# paper_id: 325 - Identification of a Novel Base J Binding Protein Complex Involved in 2 RNA Polymerase II Transcription Termination in Trypanosomes 3 Short Title: PNUTS-PP1 Regulates Transcription Termination in T
#
# cluster<(297)>
# paper_id: 637 - Vitrification after multiple rounds of sample application and blotting improves particle density on cryo-electron microscopy grids
#
# cluster<(298)>
# paper_id: 307 - HIV-1 Protease Evolvability is Affected by Synonymous Nucleotide Recoding 1 2
#
# cluster<(299)>
# paper_id: 149 - Machine learning using intrinsic genomic signatures for rapid classification of novel pathogens: COVID-19 case study
#
# cluster<(300)>
# paper_id: 425 - Comparison of real-time PCR and droplet digital PCR for the detection of Xylella fastidiosa in plants
#
# cluster<(301)>
# paper_id: 478 - A diallel of the mouse Collaborative Cross founders reveals strong strain-specific maternal effects on litter size
#
# cluster<(302)>
# paper_id: 565 - Clinical Characteristics of 2019 Coronavirus Pneumonia (COVID-19): An Updated Systematic Review
#
# cluster<(303)>
# paper_id: 333 - Mucin 4 Protects Female Mice from Coronavirus Pathogenesis
#
# cluster<(304)>
# paper_id: 41 - Estimating the Case Fatality Risk of COVID-19 using Cases from Outside China
#
# cluster<(305)>
# paper_id: 86 - TaxIt: An iterative and automated computational pipeline for untargeted strain-level identification using MS/MS spectra from pathogenic samples
#
# cluster<(306)>
# paper_id: 273 - SARS-CoV-2 transmission in cancer patients of a tertiary hospital in Wuhan
#
# cluster<(307)>
# paper_id: 586 - Breaking down of healthcare system: Mathematical modelling for controlling the novel coronavirus (2019-nCoV) outbreak in Wuhan, China
#
# cluster<(308)>
# paper_id: 786 - Title: Lipidome profiles of postnatal day 2 vaginal swabs reflect fat composition of gilt's
#
# cluster<(309)>
# paper_id: 337 - Epidemic Situation of Novel Coronavirus Pneumonia in China mainland
#
# cluster<(310)>
# paper_id: 50 - Dissecting genetic and sex-specific host heterogeneity in pathogen transmission 1 potential 2 3 4
#
# cluster<(311)>
# paper_id: 236 - Live-cell single RNA imaging reveals bursts of translational frameshifting
#
# cluster<(312)>
# paper_id: 666 - Projecting the end of the Zika virus epidemic in Latin America: a modelling analysis
#
# cluster<(313)>
# paper_id: 37 - Contesting the evidence for -1 frameshifting in immune-functioning C-C chemokine receptor 5 (CCR5) -the HIV-1 co-receptor 2
#
# cluster<(314)>
# paper_id: 213 - Transmission potential of the novel coronavirus (COVID-19) onboard the Diamond Princess Cruises Ship, 2020
#
# cluster<(315)>
# paper_id: 588 - Inflammation induced by influenza virus impairs innate control of human pneumococcal 1 carriage 2
#
# cluster<(316)>
# paper_id: 362 - Cotranslational Folding Stimulates Programmed Ribosomal Frameshifting in the Alphavirus Structural Polyprotein
#
# cluster<(317)>
# paper_id: 461 - Innate Immune Priming by cGAS as a Preparatory Countermeasure Against 1 RNA Virus Infection 2 3
#
# cluster<(318)>
# paper_id: 88 - A Mac2-positive progenitor-like microglial population survives independent of CSF1R signaling in adult mouse brain
#
# cluster<(319)>
# paper_id: 548 - Preliminary epidemiological analysis on children and adolescents with novel coronavirus disease 2019 outside Hubei Province, China: an observational study utilizing crowdsourced data
#
# cluster<(320)>
# paper_id: 776 - A hidden gene in astroviruses encodes a cell-permeabilizing protein involved in virus release
#
# cluster<(321)>
# paper_id: 636 - Single-cell Analysis of ACE2 Expression in Human Kidneys and Bladders Reveals a Potential Route of 2019-nCoV Infection
#
# cluster<(322)>
# paper_id: 509 - In silico approach to accelerate the development of mass spectrometry-based proteomics methods for detection of viral proteins: Application to COVID-19
#
# cluster<(323)>
# paper_id: 518 - Identification of a Zika NS2B-NS3pro pocket susceptible to allosteric inhibition by small molecules including qucertin rich in edible plants
#
# cluster<(324)>
# paper_id: 571 - The Seattle Flu Study: a multi-arm community-based prospective study protocol for assessing influenza prevalence, transmission, and genomic epidemiology Seattle Flu Study Investigators: Co-Investigators
#
# cluster<(325)>
# paper_id: 28 - TITLE: HIGH PREVALENCE OF STRONGYLOIDIASIS IN SPAIN: A HOSPITAL-BASED STUDY
#
# cluster<(326)>
# paper_id: 395 - A spatial model of CoVID-19 transmission in England and Wales: early spread and peak timing
#
# cluster<(327)>
# paper_id: 484 - Improving early epidemiological assessment of emerging Aedes-transmitted epidemics using historical data
#
# cluster<(328)>
# paper_id: 230 - Accelerated viral dynamics in bat cell lines, with implications for zoonotic emergence 1
#
# cluster<(329)>
# paper_id: 519 - Evaluating an Upper Respiratory Disease Panel on the Portable MinION Sequencer
#
# cluster<(330)>
# paper_id: 607 - Association between 2019-nCoV transmission and N95 respirator use
#
# cluster<(331)>
# paper_id: 801 - How to make more from exposure data? An integrated machine Author Contributions Data Accessibility Statement Running Title Machine learning and pathogen exposure risk
#
# cluster<(332)>
# paper_id: 685 - First isolation and characterisation of Alongshan virus in Russia
#
# cluster<(333)>
# paper_id: 367 - Critical Nodes of Virus-Host Interaction Revealed Through an Integrated Network Analysis
#
# cluster<(334)>
# paper_id: 422 - SARS-CoV-2 infection does not significantly cause acute renal injury: an analysis of 116 hospitalized patients with COVID-19 in a single hospital, Wuhan, China
#
# cluster<(335)>
# paper_id: 589 - Real-time monitoring the transmission potential of COVID-19 in Singapore, February 2020
#
# cluster<(336)>
# paper_id: 456 - A B
#
# cluster<(337)>
# paper_id: 597 - Preliminary identification of potential vaccine targets for the COVID-19 coronavirus (SARS-CoV-2) based on SARS- CoV immunological studies
#
# cluster<(338)>
# paper_id: 742 - Non-uniform refinement: Adaptive regularization improves single particle cryo-EM reconstruction
#
# cluster<(339)>
# paper_id: 537 - Modeling Epidemics: A Primer and Numerus Software Implementation
#
# cluster<(340)>
# paper_id: 553 - Predictions for the binding domain and potential new drug targets of 2019-nCoV
#
# cluster<(341)>
# paper_id: 798 - Comparison of severe and non-severe COVID-19 pneumonia: review and meta-analysis
#
# cluster<(342)>
# paper_id: 402 - Evaluation of Enzyme-Linked Immunoassay and Colloidal Gold- Immunochromatographic Assay Kit for Detection of Novel Coronavirus (SARS-Cov-2) Causing an Outbreak of Pneumonia (COVID-19)
#
# cluster<(343)>
# paper_id: 683 - Therapeutic effects of dipyridamole on COVID-19 patients with 1 coagulation dysfunction
#
# cluster<(344)>
# paper_id: 31 - Title: Serial interval of novel coronavirus (COVID-19) infections Correspondence to
#
# cluster<(345)>
# paper_id: 154 - Inhibition of arterivirus RNA synthesis by cyclophilin inhibitors is 3 counteracted by mutations in replicase transmembrane subunits 4 5
#
# cluster<(346)>
# paper_id: 345 - The geometry of dependence: solitary bee larvae prioritize carbohydrate over protein in
#
# cluster<(347)>
# paper_id: 494 - Title: Effects of weather-related social distancing on city-scale transmission of respiratory viruses (limit 96 characters)
#
# cluster<(348)>
# ...
#
# cluster<(677)>
# paper_id: 620 - Restriction Factor in Yeasts 2 3
#
# cluster<(678)>
# paper_id: 318 - Evolutionary rate shifts suggest species-specific adaptation events 1 in HIV-1 and SIV 6
#
# cluster<(679)>
# paper_id: 32 - Clinical features and sexual transmission potential of SARS-CoV-2 infected female patients: a descriptive study in Wuhan, China
#
# cluster<(680)>
# paper_id: 791 - Preliminary estimating the reproduction number of the coronavirus disease (COVID-19) outbreak in Republic of Korea and Italy by 5 March 2020
#
# cluster<(681)>
# paper_id: 416 - FilmArray Respiratory Panel Integrated in a field Point Of Care dispositive for the diagnosis of respiratory tract infections in rural areas in Senegal 2 Senegal
#
# cluster<(682)>
# paper_id: 306 - Structure of M pro from COVID-19 virus and discovery of its inhibitors
#
# cluster<(683)>
# paper_id: 526 - SOCRATES: An online tool leveraging a social contact data sharing initiative to assess mitigation strategies for COVID-19
#
# cluster<(684)>
# paper_id: 476 - North Carolina at Chapel Hill, 125 Mason Farm Rd
#
# cluster<(685)>
# paper_id: 792 - Adaptive Estimation for Epidemic Renewal and Phylogenetic Skyline Models
#
# cluster<(686)>
# paper_id: 694 - Rapid colorimetric detection of COVID-19 coronavirus using a reverse tran- scriptional loop-mediated isothermal amplification (RT-LAMP) diagnostic plat- form: iLACO
#
# cluster<(687)>
# paper_id: 207 - Structure of the SARS-CoV NSP12 polymerase bound to NSP7 and NSP8 co-factors
#
# cluster<(688)>
# paper_id: 40 - A quantitative framework to define the end of an outbreak: application to Ebola Virus Disease "A quantitative framework to define the end of an outbreak: application to Ebola Virus Disease"
#
# cluster<(689)>
# paper_id: 556 - Quality control implementation for universal characterization of 1 DNA and RNA viruses in clinical respiratory samples using single metagenomic next-generation sequencing workflow
#
# cluster<(690)>
# paper_id: 16 - Title: Ascertainment rate of novel coronavirus disease (COVID- 1 19) in Japan 2 Running title: Ascertainment in Japan 3 Correspondence to
#
# cluster<(691)>
# paper_id: 739 - Estimation of COVID-19 outbreak size in Italy based on international case exportations
#
# cluster<(692)>
# paper_id: 394 - A Generalized Discrete Dynamic Model for Human Epidemics
#
# cluster<(693)>
# paper_id: 442 - Association of Population migration and Coronavirus Disease 2019 epidemic control
#
# cluster<(694)>
# paper_id: 467 - Connectivity analyses of bioenergetic changes in schizophrenia: Identification of novel treatments Running title: Bioenergetic function in schizophrenia
#
# cluster<(695)>
# paper_id: 269 - Direct RNA sequencing and early evolution of SARS-CoV-2 2 3
#
# cluster<(696)>
# paper_id: 12 - Arenaviridae exoribonuclease presents genomic RNA edition capacity
#
# cluster<(697)>
# paper_id: 135 - Evaluation of the clinical characteristics of suspected or confirmed cases of COVID-19 during home care with isolation: A new retrospective analysis based on O2O
#
# cluster<(698)>
# paper_id: 356 - Ruler elements in chromatin remodelers set nucleosome array spacing and phasing
#
# cluster<(699)>
# paper_id: 485 - Estimating the Asymptomatic Proportion of 2019 Novel Coronavirus onboard the Princess Cruises Ship, 2020
#
# cluster<(700)>
# paper_id: 745 - Single cell RNA sequencing of 13 human tissues identify cell types and receptors of human coronaviruses
#
# cluster<(701)>
# paper_id: 190 - Psychological responses, behavioral changes and public perceptions during the early phase of the COVID-19 outbreak in China: a population based cross-sectional survey
#
# cluster<(702)>
# paper_id: 342 - Nanopore-based native RNA sequencing provides insights into
#
# cluster<(703)>
# paper_id: 617 - MAD1 domains in the mitotic checkpoint Coordination between discrete Mitotic Arrest Deficient 1 (MAD1) domains is required for efficient mitotic checkpoint signaling
#
# cluster<(704)>
# paper_id: 365 - Comparative analysis of gene expression in virulent and attenuated strains of infectious bronchitis virus at sub-codon resolution
#
# cluster<(705)>
# paper_id: 119 - A deterministic epidemic model for the emergence of COVID-19 in China
#
# cluster<(706)>
# paper_id: 645 - Characterisation of the faecal virome of captive and wild Tasmanian
#
# cluster<(707)>
# paper_id: 715 - Fast assessment of human receptor-binding capability of 2019 novel coronavirus (2019-nCoV)
#
# cluster<(708)>
# paper_id: 568 - Clinical significance of IgM and IgG test for diagnosis of highly suspected COVID-19 infection
#
# cluster<(709)>
# paper_id: 657 - Interpretable detection of novel human viruses from genome sequencing data
#
# cluster<(710)>
# paper_id: 437 - AI-aided design of novel targeted covalent inhibitors against SARS-CoV-2
#
# cluster<(711)>
# paper_id: 595 - Clinical Features of Patients Infected with the 2019 Novel Coronavirus (COVID-19) in Shanghai, China
#
# cluster<(712)>
# paper_id: 676 - Evaluating the impact of international airline suspensions on the early global spread of COVID-19
#
# cluster<(713)>
# paper_id: 628 - Clinical and radiographic features of cardiac injury in patients with 2019 novel coronavirus pneumonia
#
# cluster<(714)>
# paper_id: 65 - MERS-CoV spillover at the camel-human interface
#
# cluster<(715)>
# paper_id: 719 - Immunodepletion with Hypoxemia: A Potential High Risk Subtype of Coronavirus Disease 2019
#
# cluster<(716)>
# paper_id: 20 - Influenza A virus surface proteins are organized to help penetrate host mucus
#
# cluster<(717)>
# paper_id: 67 - Prediction of New Coronavirus Infection Based on a Modified SEIR Model
#
# cluster<(718)>
# paper_id: 440 - Trends in Transmissibility of 2019 Novel Coronavirus-infected Pneumonia in Wuhan and 29 Provinces in China
#
# cluster<(719)>
# paper_id: 487 - Transgenic mice expressing tunable levels of DUX4 develop characteristic facioscapulohumeral muscular dystrophy-like pathophysiology ranging in severity Title: FSHD-like transgenic mouse models of varying severity
#
# cluster<(720)>
# paper_id: 302 - Full Title: A systematic review of MERS-CoV (Middle East Respiratory Syndrome Coronavirus) 2 seroprevalence and viral RNA prevalence in dromedary camels: implications for animal vaccination
#
# cluster<(721)>
# paper_id: 295 - TITLE Containing Emerging Epidemics: a Quantitative Comparison of Quarantine and Symptom Monitoring
#
# cluster<(722)>
# paper_id: 198 - Insights into Cross-species Evolution of Novel Human Coronavirus 2019-nCoV and Defining Immune Determinants for Vaccine Development
#
# cluster<(723)>
# paper_id: 401 - Quantifying the Risk and Cost of Active Monitoring for Infectious Diseases
#
# cluster<(724)>
# paper_id: 751 - The role of absolute humidity on transmission rates of the COVID-19 outbreak
#
# cluster<(725)>
# paper_id: 729 - Aberrant pathogenic GM-CSF + T cells and inflammatory CD14 + CD16 + monocytes 1 in severe pulmonary syndrome patients of a new coronavirus 2 3
#
# cluster<(726)>
# paper_id: 707 - Potentially highly potent drugs for 2019-nCoV
#
# cluster<(727)>
# paper_id: 520 - Incubation Period and Other Epidemiological Characteristics of 2019 Novel Coronavirus Infections with Right Truncation: A Statistical Analysis of Publicly Available Case Data
#
# cluster<(728)>
# paper_id: 87 - Direct nanopore sequencing of mRNA reveals landscape of transcript isoforms in apicomplexan parasites
#
# cluster<(729)>
# paper_id: 123 - PhyloFold: Precise and Swift Prediction of RNA Secondary Structures to Incorporate Phylogeny among Homologs Associate Editor: XXXXXXX Received on XXXXX; revised on XXXXX; accepted on XXXXX
#
# cluster<(730)>
# paper_id: 618 - Diagnosis of Acute Respiratory Syndrome Coronavirus 2 Infection by Detection of Nucleocapsid Protein running title: Diagnosis of COVID-19 by N antigen detection
#
# cluster<(731)>
# paper_id: 482 - FastViromeExplorer: A Pipeline for Virus and Phage Identification and Abundance Profiling in Metagenomics Data
#
# cluster<(732)>
# paper_id: 662 - Gene expression is stronger associated with behaviour than 1 with age and fertility in ant workers 2
#
# cluster<(733)>
# paper_id: 319 - Evolving epidemiology of novel coronavirus diseases 2019 and possible interruption of local transmission outside Hubei Province in China: a descriptive and modeling study
#
# cluster<(734)>
# paper_id: 282 - A retrospective study of the clinical characteristics of COVID-19 infection in 26 children
#
# cluster<(735)>
# paper_id: 507 - Epidemiological and clinical features of 2019-nCoV acute respiratory disease cases in Chongqing municipality, China: a retrospective, descriptive, multiple-center study
#
# cluster<(736)>
# paper_id: 648 - Early Prediction of Disease Progression in 2019 Novel Coronavirus Pneumonia Patients Outside Wuhan with CT and Clinical Characteristics
#
# cluster<(737)>
# paper_id: 320 - Association of Cardiovascular Manifestations with In-hospital Outcomes in Patients with COVID-19: A Hospital Staff Data
#
# cluster<(738)>
# paper_id: 534 - Encoding of odor fear memories in the mouse olfactory cortex
#
# cluster<(739)>
# paper_id: 317 - Risk Assessment of Novel Coronavirus COVID-19 Outbreaks Outside China
#
# cluster<(740)>
# paper_id: 441 - The permeabilized SecY protein-translocation channel can serve as a nonspecific 1 sugar transporter Running Title: Bacterial nonspecific sugar transport 17 18
#
# cluster<(741)>
# paper_id: 120 - Assessing the Tendency of 2019-nCoV (COVID-19) Outbreak in China
#
# cluster<(742)>
# paper_id: 435 - Forecasting the Wuhan coronavirus (2019-nCoV) epidemics using a simple (simplistic) model
#
# cluster<(743)>
# paper_id: 753 - Rapid Detection of Novel Coronavirus (COVID-19) by Reverse Transcription- Loop-Mediated Isothermal Amplification
#
# cluster<(744)>
# paper_id: 459 - Preliminary estimation of the basic reproduction number of novel coronavirus (2019-nCoV) in China, from 2019 to 2020: A data-driven analysis in the early phase of the outbreak
#
# cluster<(745)>
# paper_id: 3 - Potential inhibitors for 2019-nCoV coronavirus M protease from clinically approved medicines
#
# cluster<(746)>
# paper_id: 308 - Monoclonal antibodies for the S2 subunit of spike of SARS-CoV cross-react with the newly-emerged SARS-CoV-2
#
# cluster<(747)>
# paper_id: 498 - Assessing the impact of a symptom-based mass screening 1 and testing intervention during a novel infectious disease
#
# cluster<(748)>
# paper_id: 635 - Transmission of human-associated microbiota along family and social networks 1 2 Authors: 3
#
# cluster<(749)>
# paper_id: 348 - The Viral Protein Corona Directs Viral Pathogenesis and Amyloid Aggregation
#
# cluster<(750)>
# paper_id: 693 - Saturation mutagenesis genome engineering of infective ΦX174 bacteriophage via unamplified oligo pools and golden gate assembly
#
# cluster<(751)>
# paper_id: 313 - Concerted 2-5A-Mediated mRNA Decay and Transcription Reprogram Protein Synthesis in dsRNA Response
#
# cluster<(752)>
# paper_id: 724 - Cryo-electron microscopy structure of the SADS-CoV spike glycoprotein 1 provides insights into an evolution of unique coronavirus spike proteins 2 3
#
# cluster<(753)>
# paper_id: 186 - Outcome reporting from protocols of clinical trials of Coronavirus Disease 2019 (COVID-19): a review
#
# cluster<(754)>
# paper_id: 69 - Bayesian mixture analysis for metagenomic community profiling
#
# cluster<(755)>
# paper_id: 591 - Highly ACE2 Expression in Pancreas May Cause Pancreas Damage After SARS-CoV-2 Infection
#
# cluster<(756)>
# paper_id: 292 - Recombination and convergent evolution led to the emergence of 2019 Wuhan coronavirus
#
# cluster<(757)>
# paper_id: 713 - Epidemiological and clinical features of COVID-19 patients with and without pneumonia in Beijing, China
#
# cluster<(758)>
# paper_id: 587 - Stochastic discrete epidemic modeling of COVID-19 transmission in the Province of Shaanxi incorporating public health intervention and case importation
#
# cluster<(759)>
# paper_id: 164 - RNA-binding activity of TRIM25 is mediated by its PRY/SPRY domain and is required for ubiquitination E-mail: Gracjan.Michlewski@ed.ac.uk Running Title: RNA-binding protein TRIM25 KEYWORDS: Novel RNA-binding proteins, TRIM25, RNA-protein interactions, RNA- binding domain, PRY/SPRY
#
# cluster<(760)>
# paper_id: 721 - Clinical characteristics of 25 death cases with COVID-19: a retrospective review of medical records in a single medical center
#
# cluster<(761)>
# paper_id: 692 - Estimating the infection and case fatality ratio for COVID-19 using age-adjusted data from the outbreak on the Diamond Princess cruise ship
#
# cluster<(762)>
# paper_id: 446 - Evaluation of the potential incidence of COVID-19 and effectiveness of contention measures in Spain: a data-driven approach
#
# cluster<(763)>
# paper_id: 760 - Clinical characteristics of 82 death cases with COVID-19
#
# cluster<(764)>
# paper_id: 156 - ACE2 Expression in Kidney and Testis May Cause Kidney and Testis Damage After 2019-nCoV Infection
#
# cluster<(765)>
# paper_id: 212 - Rapid Detection of SARS-CoV-2 Using Reverse transcription RT-LAMP method
#
# cluster<(766)>
# paper_id: 604 - A speed-fidelity trade-off determines the mutation rate and virulence of an RNA virus 2 3 Running Title: Speed-fidelity trade-off 4 5 6 7
#
# cluster<(767)>
# paper_id: 105 - Single-cell RNA expression profiling of ACE2, the putative receptor of Wuhan 2019-nCoV, in the nasal tissue
#
# cluster<(768)>
# paper_id: 649 - The Role of Proton Transport in Gating Current in a Voltage Gated Ion Channel, as Shown by Quantum Calculations
#
# cluster<(769)>
# paper_id: 254 - REPROGRAMMED PTEROPUS BAT STEM CELLS PRESENT DISTINCT IMMUNE SIGNATURE AND ARE HIGHLY PERMISSIVE FOR 2 HENIPAVIRUSES 3 4 5 Summary sentence: Somatic reprogramming provides new bat stem cells with unique immune
#
# cluster<(770)>
# paper_id: 539 - HUMAN BOCAVIRUS PREVALENCE IN CHILDREN WITH ACUTE GASTROENTERITIS FROM RURAL COMMUNITIES IN THE NORTHEN REGION OF SOUTH AFRICA Running Head: Human Bocavirus in children with AGE
#
# cluster<(771)>
# paper_id: 673 -
#
# cluster<(772)>
# paper_id: 515 - COVID-19 in Japan: What could happen in the future?
#
# cluster<(773)>
# paper_id: 358 - Specific ACE2 Expression in Cholangiocytes May Cause Liver Damage After 2019-nCoV Infection
#
# cluster<(774)>
# paper_id: 642 - Real-Time Estimation of the Risk of Death from Novel Coronavirus (COVID-19) Infection: Inference Using Exported Cases
#
# cluster<(775)>
# paper_id: 177 -
#
# cluster<(776)>
# paper_id: 774 - ARTICLE A case for a reverse-frame coding sequence in a group of positive-sense RNA viruses
#
# cluster<(777)>
# paper_id: 725 -
#
# cluster<(778)>
# paper_id: 583 - The MHC class-II HLA-DR receptor mediates bat influenza A-like H17N10 virus entry 1 into mammalian cells 2
#
# cluster<(779)>
# paper_id: 382 -
#
# cluster<(780)>
# paper_id: 189 -
#
# cluster<(781)>
# paper_id: 579 -
#
# cluster<(782)>
# paper_id: 627 -
#
# cluster<(783)>
# paper_id: 444 -
#
# cluster<(784)>
# paper_id: 328 - In silico Design of novel Multi-epitope recombinant Vaccine based on Coronavirus surface 2 glycoprotein 3 4
#
# cluster<(785)>
# paper_id: 372 -
#
# cluster<(786)>
# paper_id: 224 - Structure-Guided Mutagenesis Alters Deubiquitinating Activity 2 and Attenuates Pathogenesis of a Murine Coronavirus
#
# cluster<(787)>
# paper_id: 312 -
#
# cluster<(788)>
# paper_id: 210 - A nematode-specific gene underlies bleomycin-response variation in Caenorhabditis elegans 1 2
#
# cluster<(789)>
# paper_id: 525 -
#
# cluster<(790)>
# paper_id: 557 - Nowcasting by Bayesian Smoothing: A flexible, generalizable model for real-time epidemic tracking
#
# cluster<(791)>
# paper_id: 638 -
#
# cluster<(792)>
# paper_id: 283 -
#
# cluster<(793)>
# paper_id: 399 -
#
# cluster<(794)>
# paper_id: 458 -
#
# cluster<(795)>
# paper_id: 477 - EPS8 facilitates uncoating of influenza A virus
#
# cluster<(796)>
# paper_id: 793 - Homologous Recombination as an Evolutionary Force in 1 African Swine Fever Viruses
#
# cluster<(797)>
# paper_id: 704 -
#
# cluster<(798)>
# paper_id: 555 - Stress-Induced Transcriptional Memory Accelerates Promoter-Proximal Pause-Release and Decelerates Termination over Mitotic Divisions 2! 3!
#
# cluster<(799)>
# paper_id: 463 -
#
# cluster<(800)>
# paper_id: 669 -
#
# cluster<(801)>
# paper_id: 624 -
#
# cluster<(802)>
# paper_id: 582 - First evidence of host range expansion in virophages and its potential impact on giant viruses and host cells

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans

embedder = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# 100%|██████████| 405M/405M [01:04<00:00, 6.28MB/s]

# %%
titles_embeddings = embedder.encode(titles)

# perform k-mean clustering
n_clusters = 5
clustering_model = KMeans(n_clusters=n_clusters)
clustering_model.fit(titles_embeddings)
cluster_assignment = clustering_model.labels_

clustered_titles = [[] for i in range(n_clusters)]
for title_id, cluster_id in enumerate(cluster_assignment):
    cluster = titles_cluster[title_id]
    clustered_titles.append(cluster)

for i, cluster in enumerate(clustered_titles):
    if cluster:
        title, paper_id = cluster[0], cluster[1]      
        print(f'<cluster={i+1}, paper_id={paper_id}>')
        print(f'title: {title}')
# Out:
# <cluster=6, paper_id=569>
# title: A PROOF OF CONCEPT FOR A SYNDROMIC SURVEILLANCE SYSTEM BASED ON ROUTINE AMBULANCE RECORDS IN THE SOUTH-WEST OF ENGLAND, FOR THE INFLUENZA SEASON A PREPRINT
# <cluster=7, paper_id=339>
# title: MUC5AC drives COPD exacerbation severity through amplification of virus-induced airway inflammation
# <cluster=8, paper_id=643>
# title: Kin and group selection are both flawed but useful data analysis tools
# <cluster=9, paper_id=479>
# title: A preliminary study on serological assay for severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) in 238 2 admitted hospital patients
# <cluster=10, paper_id=123>
# title: PhyloFold: Precise and Swift Prediction of RNA Secondary Structures to Incorporate Phylogeny among Homologs Associate Editor: XXXXXXX Received on XXXXX; revised on XXXXX; accepted on XXXXX
# <cluster=11, paper_id=576>
# title: Genotypic diversity, circulation patterns, and co-detections among rhinoviruses in Queensland, 2001
# <cluster=12, paper_id=227>
# title: Genetic control of the HDL proteome
# <cluster=13, paper_id=462>
# title: Title: 2 GI-16 lineage (624/I or Q1), there and Back Again: the 3 history of one of the major threat for poultry farming of our 4 era. 5 6 Short title: 7 Phylodynamic analysis of IBV GI-16 lineage
# <cluster=14, paper_id=587>
# title: Stochastic discrete epidemic modeling of COVID-19 transmission in the Province of Shaanxi incorporating public health intervention and case importation
# <cluster=15, paper_id=715>
# title: Fast assessment of human receptor-binding capability of 2019 novel coronavirus (2019-nCoV)
# <cluster=16, paper_id=114>
# title: Fitness barriers limit reversion of a proofreading-deficient coronavirus 1 2
# <cluster=17, paper_id=344>
# title: Mating strategy is determinant of Adenovirus prevalence in European bats 2
# <cluster=18, paper_id=313>
# title: Concerted 2-5A-Mediated mRNA Decay and Transcription Reprogram Protein Synthesis in dsRNA Response
# <cluster=19, paper_id=318>
# title: Evolutionary rate shifts suggest species-specific adaptation events 1 in HIV-1 and SIV 6
# <cluster=20, paper_id=347>
# title: LY6E impairs coronavirus fusion and confers immune control of viral disease
# <cluster=21, paper_id=392>
# title: Life course exposures continually shape antibody profile and risk of seroconversion to influenza
# <cluster=22, paper_id=446>
# title: Evaluation of the potential incidence of COVID-19 and effectiveness of contention measures in Spain: a data-driven approach
# <cluster=23, paper_id=53>
# title: A Toolkit for Rapid Modular Construction of Biological Circuits in Mammalian Cells
# <cluster=24, paper_id=356>
# title: Ruler elements in chromatin remodelers set nucleosome array spacing and phasing
# <cluster=25, paper_id=220>
# title: Clinical Characteristics of SARS-CoV-2 Pneumonia Compared to Controls in Chinese Han Population
# <cluster=26, paper_id=65>
# title: MERS-CoV spillover at the camel-human interface
# <cluster=27, paper_id=289>
# title: Self-assembly of the RZZ complex into filaments drives kinetochore expansion in the absence of microtubule attachment
# <cluster=28, paper_id=14>
# title: Systematic Review of the Registered Clinical Trials of Coronavirus Diseases 2019 (COVID-19)
# <cluster=29, paper_id=440>
# title: Trends in Transmissibility of 2019 Novel Coronavirus-infected Pneumonia in Wuhan and 29 Provinces in China
# <cluster=30, paper_id=577>
# title: Aerosol and surface stability of HCoV-19 (SARS-CoV-2) compared to SARS-CoV-1 6
# <cluster=31, paper_id=493>
# title: G-quadruplex forming sequences in the genome of all known human viruses: a comprehensive guide Running title: Presence and conservation of G4s in human viruses
# <cluster=32, paper_id=555>
# title: Stress-Induced Transcriptional Memory Accelerates Promoter-Proximal Pause-Release and Decelerates Termination over Mitotic Divisions 2! 3!
# <cluster=33, paper_id=743>
# title: A Novel Method for the Estimation of a Dynamic Effective Reproduction Number (Dynamic-R) in the CoViD-19 Outbreak A Novel Method for the Estimation of a Dynamic Effective Reproduction Number (Dynamic-R) in the CoViD-19 Outbreak
# <cluster=34, paper_id=111>
# title: Mutation of Ebola virus VP35 Ser129 uncouples interferon antagonist and replication functions
# <cluster=35, paper_id=753>
# title: Rapid Detection of Novel Coronavirus (COVID-19) by Reverse Transcription- Loop-Mediated Isothermal Amplification
# <cluster=36, paper_id=539>
# title: HUMAN BOCAVIRUS PREVALENCE IN CHILDREN WITH ACUTE GASTROENTERITIS FROM RURAL COMMUNITIES IN THE NORTHEN REGION OF SOUTH AFRICA Running Head: Human Bocavirus in children with AGE
# <cluster=37, paper_id=46>
# title: Structure of the chromatin remodelling enzyme Chd1 bound to a ubiquitinylated nucleosome
# <cluster=38, paper_id=628>
# title: Clinical and radiographic features of cardiac injury in patients with 2019 novel coronavirus pneumonia
# <cluster=39, paper_id=596>
# title: Domestication reprogrammed the budding yeast life cycle
# <cluster=40, paper_id=481>
# title: Fractional Dosing of Yellow Fever Vaccine to Extend Supply: A Modeling Study 1 2 AUTHORS 3
# <cluster=41, paper_id=646>
# title: Recombinant rotaviruses rescued by reverse genetics reveal the role of NSP5 hyperphosphorylation in the 2 assembly of viral factories 3 4
# <cluster=42, paper_id=787>
# title: Deep learning Enables Accurate Diagnosis of Novel Coronavirus (COVID-19) with CT images
# <cluster=43, paper_id=16>
# title: Title: Ascertainment rate of novel coronavirus disease (COVID- 1 19) in Japan 2 Running title: Ascertainment in Japan 3 Correspondence to
# <cluster=44, paper_id=775>
# title: participated in study design
# <cluster=45, paper_id=693>
# title: Saturation mutagenesis genome engineering of infective ΦX174 bacteriophage via unamplified oligo pools and golden gate assembly
# <cluster=46, paper_id=700>
# title: Gene birth contributes to structural disorder encoded by overlapping genes
# <cluster=47, paper_id=624>
# title:
# <cluster=48, paper_id=513>
# title: Screening of FDA-approved drugs using a MERS-CoV clinical isolate from South Korea identifies potential therapeutic options for COVID-19
# <cluster=49, paper_id=491>
# title:
# <cluster=50, paper_id=394>
# title: A Generalized Discrete Dynamic Model for Human Epidemics
# <cluster=51, paper_id=454>
# title: Title: An Augmented Aging Process in Brain White Matter in HIV
# <cluster=52, paper_id=243>
# title: Substantial undocumented infection facilitates the rapid dissemination of novel coronavirus (COVID-19)
# <cluster=53, paper_id=797>
# title: Evolutionary proteomics uncovers ciliary signaling components 1 2
# <cluster=54, paper_id=187>
# title: Title Analysis of the epidemic growth of the early 2019-nCoV outbreak using internationally confirmed cases
# <cluster=55, paper_id=282>
# title: A retrospective study of the clinical characteristics of COVID-19 infection in 26 children
# <cluster=56, paper_id=299>
# title: Quantifying transmission of emerging zoonoses: 3 Using mathematical models to maximize the value of surveillance data 4 5 6 7
# <cluster=57, paper_id=476>
# title: North Carolina at Chapel Hill, 125 Mason Farm Rd
# <cluster=58, paper_id=792>
# title: Adaptive Estimation for Epidemic Renewal and Phylogenetic Skyline Models
# <cluster=59, paper_id=328>
# title: In silico Design of novel Multi-epitope recombinant Vaccine based on Coronavirus surface 2 glycoprotein 3 4
# <cluster=60, paper_id=336>
# title: Synergetic effect of non-complementary 5' AT-rich sequences on the development of a multiplex TaqMan real-time PCR for specific and robust detection of Clavibacter michiganensis and C. michiganensis subsp. nebraskensis
# <cluster=61, paper_id=469>
# title: Lipocalin-2 is a Sensitive and Specific Marker of Bacterial Infection in Children
# <cluster=62, paper_id=178>
# title: Direct nucleic acid analysis of mosquitoes for high fidelity species identification and 1 detection of Wolbachia using a cellphone 2 3
# <cluster=63, paper_id=388>
# title: Profiling ACE2 expression in colon tissue of healthy adults and colorectal cancer patients by single-cell transcriptome analysis
# <cluster=64, paper_id=241>
# title: Expanding the size limit of RNA viruses: Evidence of a novel divergent nidovirus in California sea hare, with a ∼ 35.9 kb virus genome
# <cluster=65, paper_id=611>
# title: Chronic infections can shape epidemic exposure: Pathogen co-occurrence networks in the Serengeti lions
# <cluster=66, paper_id=353>
# title: A novel framework for inferring parameters of transmission 1 from viral sequence data
# <cluster=67, paper_id=660>
# title: Viral long-term evolutionary strategies favor stability 1 over proliferation
# <cluster=68, paper_id=647>
# title: Virological assessment of hospitalized cases of coronavirus disease 2019 *equal contribution **senior authors with equal contribution
# <cluster=69, paper_id=160>
# title: Profiling the immune vulnerability landscape of the 2019 Novel Coronavirus
# <cluster=70, paper_id=329>
# title: Estimation of local novel coronavirus (COVID-19) cases in Wuhan, China from off-site reported cases and population flow data from different sources
# <cluster=71, paper_id=645>
# title: Characterisation of the faecal virome of captive and wild Tasmanian
# <cluster=72, paper_id=7>
# title: Estimation of country-level basic reproductive ratios for novel Coronavirus (COVID-19) using synthetic contact matrices
# <cluster=73, paper_id=791>
# title: Preliminary estimating the reproduction number of the coronavirus disease (COVID-19) outbreak in Republic of Korea and Italy by 5 March 2020
# <cluster=74, paper_id=107>
# title: Origins and Evolution of the Global RNA Virome
# <cluster=75, paper_id=296>
# title: Diversity of Archaea Domain in Cuatro Cienegas Basin: Archaean Domes 1 2
# <cluster=76, paper_id=275>
# title: The 2019-new coronavirus epidemic: evidence for virus evolution
# <cluster=77, paper_id=609>
# title: Reduction and Functional Exhaustion of T Cells in Patients with Coronavirus Disease 2019 (COVID-19)
# <cluster=78, paper_id=527>
# title: Cryo-EM Structure of the 2019-nCoV Spike in the Prefusion Conformation
# <cluster=79, paper_id=152>
# title: Title: Interventions targeting air travellers early in the pandemic may delay local outbreaks of SARS-CoV-2
# <cluster=80, paper_id=799>
# title: A novel totivirus alters gene expression and vacuolar morphology in Malassezia cells and induces a TLR3-mediated inflammatory immune response Running Head: A novel totivirus in Malassezia
# <cluster=81, paper_id=668>
# title: A comprehensive annotation and differential expression analysis of short and long non-coding RNAs in 16 bat genomes
# <cluster=82, paper_id=692>
# title: Estimating the infection and case fatality ratio for COVID-19 using age-adjusted data from the outbreak on the Diamond Princess cruise ship
# <cluster=83, paper_id=141>
# title: Hotspots of aberrant enhancer activity in fibrolamellar carcinoma reveal molecular mechanisms of oncogenesis and intrinsic drug resistance
# <cluster=84, paper_id=384>
# title: Sensitive one-step isothermal detection of pathogen-derived RNAs
# <cluster=85, paper_id=383>
# title: Title: Viruses are a dominant driver of protein adaptation in mammals
# <cluster=86, paper_id=334>
# title: Full Title: Comparisons of a Novel Air Sampling Filter Material, Wash Buffers and 2 Extraction Methods in the Detection and Quantification of Influenza Virus 3 Short title: Comparisons of Air Sampling Filter Materials for the Detection Quantification 4 of Influenza Virus CPUB-Occup & Environ Hea
# <cluster=87, paper_id=575>
# title: CHOP and IRE1α-XBP1/JNK signaling promote Newcastle Disease Virus induced apoptosis and benefit virus proliferation
# <cluster=88, paper_id=669>
# title:
# <cluster=89, paper_id=260>
# title: Exploring diseases/traits and blood proteins causally related to expression of ACE2, the putative receptor of 2019-nCov: A Mendelian Randomization analysis
# <cluster=90, paper_id=342>
# title: Nanopore-based native RNA sequencing provides insights into
# <cluster=91, paper_id=526>
# title: SOCRATES: An online tool leveraging a social contact data sharing initiative to assess mitigation strategies for COVID-19
# <cluster=92, paper_id=557>
# title: Nowcasting by Bayesian Smoothing: A flexible, generalizable model for real-time epidemic tracking
# <cluster=93, paper_id=487>
# title: Transgenic mice expressing tunable levels of DUX4 develop characteristic facioscapulohumeral muscular dystrophy-like pathophysiology ranging in severity Title: FSHD-like transgenic mouse models of varying severity
# <cluster=94, paper_id=331>
# title: Mycroft-West et al. (2020) Running title: SARS-CoV-2 surface S1 Receptor Binding Domain binds heparin The 2019 coronavirus (SARS-CoV-2) surface protein (Spike) S1 Receptor Binding Domain undergoes conformational change upon heparin binding
# <cluster=95, paper_id=79>
# title: Using heterogeneity in the population structure of U.S. swine farms to compare transmission models for porcine epidemic diarrhoea
# <cluster=96, paper_id=719>
# title: Immunodepletion with Hypoxemia: A Potential High Risk Subtype of Coronavirus Disease 2019
# <cluster=97, paper_id=87>
# title: Direct nanopore sequencing of mRNA reveals landscape of transcript isoforms in apicomplexan parasites
# <cluster=98, paper_id=662>
# title: Gene expression is stronger associated with behaviour than 1 with age and fertility in ant workers 2
# <cluster=99, paper_id=10>
# title: Vorpal: A novel RNA virus feature- 1 extraction algorithm demonstrated 2 through interpretable genotype-to- 3 phenotype linear models 4 5
# <cluster=100, paper_id=724>
# title: Cryo-electron microscopy structure of the SADS-CoV spike glycoprotein 1 provides insights into an evolution of unique coronavirus spike proteins 2 3
# <cluster=101, paper_id=30>
# title: Tissue Tropism and Transmission Ecology Predict Virulence of Human RNA Viruses 2
# <cluster=102, paper_id=464>
# title: Social history and exposure to pathogen signals modulate social status effects on gene regulation in rhesus macaques
# <cluster=103, paper_id=793>
# title: Homologous Recombination as an Evolutionary Force in 1 African Swine Fever Viruses
# <cluster=104, paper_id=463>
# title:
# <cluster=105, paper_id=12>
# title: Arenaviridae exoribonuclease presents genomic RNA edition capacity
# <cluster=106, paper_id=20>
# title: Influenza A virus surface proteins are organized to help penetrate host mucus
# <cluster=107, paper_id=731>
# title: DEN-IM: Dengue Virus identification from shotgun and targeted metagenomics
# <cluster=108, paper_id=402>
# title: Evaluation of Enzyme-Linked Immunoassay and Colloidal Gold- Immunochromatographic Assay Kit for Detection of Novel Coronavirus (SARS-Cov-2) Causing an Outbreak of Pneumonia (COVID-19)
# <cluster=109, paper_id=450>
# title: 2 3 TIM-1 SERVES AS A NONREDUNDANT RECEPTOR FOR EBOLA 4 VIRUS, ENHANCING VIREMIA AND PATHOGENESIS 5 6
# <cluster=110, paper_id=482>
# title: FastViromeExplorer: A Pipeline for Virus and Phage Identification and Abundance Profiling in Metagenomics Data
# <cluster=111, paper_id=681>
# title: Productive infection of field strains of avian coronavirus infectious bronchitis virus in chicken peripheral blood-derived monocytes
# <cluster=112, paper_id=498>
# title: Assessing the impact of a symptom-based mass screening 1 and testing intervention during a novel infectious disease
# <cluster=113, paper_id=264>
# title: Evidence of recombination in coronaviruses implicating pangolin origins of nCoV- 2019
# <cluster=114, paper_id=592>
# title: Severe acute respiratory syndrome-related coronavirus: The species and its viruses -a statement of the Coronavirus Study Group
# <cluster=115, paper_id=127>
# title: Quantifying the success of measles vaccination campaigns in the Rohingya refugee camps
# <cluster=116, paper_id=135>
# title: Evaluation of the clinical characteristics of suspected or confirmed cases of COVID-19 during home care with isolation: A new retrospective analysis based on O2O
# <cluster=117, paper_id=321>
# title: How to differentiate COVID-19 pneumonia from heart failure with computed tomography at initial medical contact during epidemic period Running title: CT imaging for COVID-19 and heart failure
# <cluster=118, paper_id=175>
# title: Geometric coupling of helicoidal ramps and curvature-inducing proteins in organelle membranes
# <cluster=119, paper_id=657>
# title: Interpretable detection of novel human viruses from genome sequencing data
# <cluster=120, paper_id=272>
# title: Tuning antiviral CD8 T-cell response via proline-altered peptide ligand vaccination
# <cluster=121, paper_id=185>
# title: Article: Discoveries On the causes of evolutionary transition:transversion bias
# <cluster=122, paper_id=459>
# title: Preliminary estimation of the basic reproduction number of novel coronavirus (2019-nCoV) in China, from 2019 to 2020: A data-driven analysis in the early phase of the outbreak
# <cluster=123, paper_id=790>
# title: Animal virus ecology and evolution are shaped by the virus host-body
# <cluster=124, paper_id=139>
# title: Modification of primary amines to higher order amines reduces in vivo hematological and immunotoxicity of cationic nanocarriers through TLR4 and complement pathways
# <cluster=125, paper_id=499>
# title: Title: ACP risk grade: a simple mortality index for patients with confirmed or suspected severe acute respiratory syndrome coronavirus 2 disease (COVID-19) during the early stage of outbreak in Wuhan
# <cluster=126, paper_id=721>
# title: Clinical characteristics of 25 death cases with COVID-19: a retrospective review of medical records in a single medical center
# <cluster=127, paper_id=515>
# title: COVID-19 in Japan: What could happen in the future?
# <cluster=128, paper_id=41>
# title: Estimating the Case Fatality Risk of COVID-19 using Cases from Outside China
# <cluster=129, paper_id=740>
# title: Title: Candidate targets for immune responses to 2019-Novel Coronavirus (nCoV): sequence homology-and bioinformatic-based predictions
# <cluster=130, paper_id=618>
# title: Diagnosis of Acute Respiratory Syndrome Coronavirus 2 Infection by Detection of Nucleocapsid Protein running title: Diagnosis of COVID-19 by N antigen detection
# <cluster=131, paper_id=696>
# title: VADR: validation and annotation of virus sequence submissions to GenBank
# <cluster=132, paper_id=93>
# title: An amino acid motif in HLA-DRβ1 distinguishes patients with uveitis in juvenile idiopathic arthritis
# <cluster=133, paper_id=40>
# title: A quantitative framework to define the end of an outbreak: application to Ebola Virus Disease "A quantitative framework to define the end of an outbreak: application to Ebola Virus Disease"
# <cluster=134, paper_id=340>
# title: Rapid metagenomic characterization of a case of imported COVID-19 in Cambodia
# <cluster=135, paper_id=648>
# title: Early Prediction of Disease Progression in 2019 Novel Coronavirus Pneumonia Patients Outside Wuhan with CT and Clinical Characteristics
# <cluster=136, paper_id=594>
# title: Title: Bat coronavirus phylogeography in the western Indian Ocean Running title: Bat coronavirus in the western Indian Ocean Author affiliations
# <cluster=137, paper_id=3>
# title: Potential inhibitors for 2019-nCoV coronavirus M protease from clinically approved medicines
# <cluster=138, paper_id=559>
# title:
# <cluster=139, paper_id=365>
# title: Comparative analysis of gene expression in virulent and attenuated strains of infectious bronchitis virus at sub-codon resolution
# <cluster=140, paper_id=11>
# title: Predicting the global mammalian viral 1 sharing network using phylogeography
# <cluster=141, paper_id=277>
# title: Autonomous Region, China. heb-001001@163.com (Biao He); michael.carr@ucd.ie
# <cluster=142, paper_id=105>
# title: Single-cell RNA expression profiling of ACE2, the putative receptor of Wuhan 2019-nCoV, in the nasal tissue
# <cluster=143, paper_id=620>
# title: Restriction Factor in Yeasts 2 3
# <cluster=144, paper_id=346>
# title: Strong evolutionary convergence of receptor-binding protein spike between COVID-19 and SARS-related coronaviruses
# <cluster=145, paper_id=51>
# title: Facemask shortage and the coronavirus disease (COVID-19) outbreak: Reflection on public health measures
# <cluster=146, paper_id=767>
# title: Inactivating porcine coronavirus before nuclei acid isolation with the temperature higher than 56 o C damages its genome integrity seriously
# <cluster=147, paper_id=252>
# title: Noroviruses subvert the core stress granule component G3BP1 to promote viral VPg-dependent translation
# <cluster=148, paper_id=67>
# title: Prediction of New Coronavirus Infection Based on a Modified SEIR Model
# <cluster=149, paper_id=568>
# title: Clinical significance of IgM and IgG test for diagnosis of highly suspected COVID-19 infection
# <cluster=150, paper_id=349>
# title: The IFN response in bat cells consists of canonical and non-canonical ISGs with unique temporal expression kinetics
# <cluster=151, paper_id=276>
# title: Design: An assay based on single-polypeptide-chain heterodimeric A2AR/D2R and non-oligomerized fusions for in vivo analysis of their allosteric receptor-receptor interactions
# <cluster=152, paper_id=538>
# title: Statistics based predictions of coronavirus 2019-nCoV spreading in mainland China
# <cluster=153, paper_id=524>
# title: Nelfinavir was predicted to be a potential inhibitor of 2019-nCov main protease by an integrative approach combining homology modelling, molecular docking and binding free energy calculation
# <cluster=154, paper_id=570>
# title: COVID-19 in Wuhan: Immediate Psychological Impact on 5062 Health Workers
# <cluster=155, paper_id=411>
# title: Coronavirus S protein-induced fusion is blocked prior to hemifusion by Abl kinase inhibitors
# <cluster=156, paper_id=158>
# title: Beyond R 0 : the importance of contact tracing when predicting epidemics
# <cluster=157, paper_id=311>
# title: Epidemiologic Characteristics of COVID-19 in Guizhou, China Affiliations: Guizhou Center for Disease Control and Prevention Abstract
# <cluster=158, paper_id=428>
# title: The alkyl side chain of PACA nanoparticles dictates the impact on cellular stress responses and the mode of particle-induced cell death
# <cluster=159, paper_id=708>
# title: Salt Effects on the Thermodynamics of a Frameshifting RNA Pseudoknot under Tension
# <cluster=160, paper_id=571>
# title: The Seattle Flu Study: a multi-arm community-based prospective study protocol for assessing influenza prevalence, transmission, and genomic epidemiology Seattle Flu Study Investigators: Co-Investigators
# <cluster=161, paper_id=508>
# title: Ministry of Health, Kinshasa, Democratic Republic of Congo g. School of Public Health
# <cluster=162, paper_id=84>
# title: Remote control of neural function by X-ray-induced scintillation
# <cluster=163, paper_id=32>
# title: Clinical features and sexual transmission potential of SARS-CoV-2 infected female patients: a descriptive study in Wuhan, China
# <cluster=164, paper_id=523>
# title: Epidemic size of novel coronavirus-infected pneumonia in the Epicenter Wuhan: using data of five-countries' evacuation action
# <cluster=165, paper_id=695>
# title: Diarrhea may be underestimated: a missing link in 2019 novel coronavirus
# <cluster=166, paper_id=194>
# title: SPINT2 inhibits proteases involved in activation of both influenza viruses and metapneumoviruses 1 2
# <cluster=167, paper_id=452>
# title: Clinical Characteristics of Two Human to Human Transmitted Coronaviruses: Corona Virus Disease 2019 versus Middle East Respiratory Syndrome Coronavirus
# <cluster=168, paper_id=116>
# title: Deoxynivalenol Promotes Porcine Epidemic Diarrhea Virus Infection and 2 Aggravates Gut Barrier Injury
# <cluster=169, paper_id=540>
# title: 2 A systematic review and evaluation of Zika virus forecasting and prediction research during a 3 public health emergency of international concern 4 5 Kobres P
# <cluster=170, paper_id=599>
# title: Potential T-cell and B-cell Epitopes of 2019-nCoV
# <cluster=171, paper_id=90>
# title: Restoration of leukomonocyte counts is associated with viral 1 clearance in COVID-19 hospitalized patients 2 3
# <cluster=172, paper_id=316>
# title: The Impact of Host-Based Early Warning on Disease Outbreaks
# <cluster=173, paper_id=745>
# title: Single cell RNA sequencing of 13 human tissues identify cell types and receptors of human coronaviruses
# <cluster=174, paper_id=303>
# title: Prevalence and clinical features of 2019 novel coronavirus disease (COVID-19) in the Fever Clinic of a teaching hospital in Beijing: a single-center, retrospective study
# <cluster=175, paper_id=704>
# title:
# <cluster=176, paper_id=442>
# title: Association of Population migration and Coronavirus Disease 2019 epidemic control
# <cluster=177, paper_id=97>
# title: Novel Function of Bluetongue Virus NS3 Protein in Regulation of the MAPK/ERK Signaling Pathway 2 3
# <cluster=178, paper_id=309>
# title: The deubiquitinating activity of Middle East respiratory syndrome 2 coronavirus papain-like protease delays the innate immune response 3 and enhances virulence in a mouse model 4 5 Robert
# <cluster=179, paper_id=431>
# title: Astrovirus in Reunion Free-tailed Bat (Mormopterus francoismoutoui)
# <cluster=180, paper_id=265>
# title: Effective containment explains sub-exponential growth in confirmed cases of recent COVID-19 outbreak in Mainland China
# <cluster=181, paper_id=640>
# title: 23 of the 2019-nCoV sequence
# <cluster=182, paper_id=164>
# title: RNA-binding activity of TRIM25 is mediated by its PRY/SPRY domain and is required for ubiquitination E-mail: Gracjan.Michlewski@ed.ac.uk Running Title: RNA-binding protein TRIM25 KEYWORDS: Novel RNA-binding proteins, TRIM25, RNA-protein interactions, RNA- binding domain, PRY/SPRY
# <cluster=183, paper_id=234>
# title: Title: Intrinsic growth rules of patients infected, dead and cured with 2019 novel 1 coronavirus in mainland China 2
# <cluster=184, paper_id=389>
# title: Ensemble Feature Selection and Meta-Analysis of Cancer miRNA Biomarkers
# <cluster=185, paper_id=534>
# title: Encoding of odor fear memories in the mouse olfactory cortex
# <cluster=186, paper_id=138>
# title: Molecular basis for the evolution of species-specific hemoglobin capture by pathogenic 1 Staphylococcus 2
# <cluster=187, paper_id=29>
# title: Characterizing the transmission and identifying the control strategy for COVID-19 through epidemiological modeling
# <cluster=188, paper_id=326>
# title: Designing Effective small interfering RNA for Post-Transcriptional Silencing of Human GREM1: A Comprehensive Bioinformatics Approach
# <cluster=189, paper_id=320>
# title: Association of Cardiovascular Manifestations with In-hospital Outcomes in Patients with COVID-19: A Hospital Staff Data
# <cluster=190, paper_id=156>
# title: ACE2 Expression in Kidney and Testis May Cause Kidney and Testis Damage After 2019-nCoV Infection
# <cluster=191, paper_id=119>
# title: A deterministic epidemic model for the emergence of COVID-19 in China
# <cluster=192, paper_id=68>
# title: Precautions are Needed for COVID-19 Patients with Coinfection of Common Respiratory Pathogens
# <cluster=193, paper_id=489>
# title: Evaluating performance of metagenomic characterization algorithms using in silico datasets generated with FASTQSim
# <cluster=194, paper_id=39>
# title: The Israeli Acute Paralysis Virus IRES captures host
# <cluster=195, paper_id=543>
# title: Distinct spread of DNA and RNA viruses among mammals amid prominent role of domestic species
# <cluster=196, paper_id=520>
# title: Incubation Period and Other Epidemiological Characteristics of 2019 Novel Coronavirus Infections with Right Truncation: A Statistical Analysis of Publicly Available Case Data
# <cluster=197, paper_id=99>
# title: Distribution of the 2019-nCoV Epidemic and Correlation with Population Emigration from Wuhan, China
# <cluster=198, paper_id=95>
# title: Title: Risk of disease spillover from dogs to wild carnivores in Kanha Tiger Reserve, India. Running head: Disease spillover from dogs to carnivores
# <cluster=199, paper_id=259>
# title: Host and infectivity prediction of Wuhan 2019 novel coronavirus using deep learning algorithm
# <cluster=200, paper_id=56>
# title: Early epidemiological analysis of the 2019-nCoV outbreak based on a crowdsourced data
# <cluster=201, paper_id=710>
# title: Airway IRF7 hi versus IRF7 lo molecular response patterns determine clinical phenotypes in 1 children with acute wheezing 2 3
# <cluster=202, paper_id=401>
# title: Quantifying the Risk and Cost of Active Monitoring for Infectious Diseases
# <cluster=203, paper_id=407>
# title: Insufficiency in airway interferon activation defines clinical severity to infant RSV infection. Running Title: Airway IFN Signaling in RSV Infection
# <cluster=204, paper_id=707>
# title: Potentially highly potent drugs for 2019-nCoV
# <cluster=205, paper_id=355>
# title: Chemogenetic evidence that rapid neuronal de novo protein synthesis is 3 required for consolidation of long-term memory Introduction 82
# <cluster=206, paper_id=69>
# title: Bayesian mixture analysis for metagenomic community profiling
# <cluster=207, paper_id=190>
# title: Psychological responses, behavioral changes and public perceptions during the early phase of the COVID-19 outbreak in China: a population based cross-sectional survey
# <cluster=208, paper_id=306>
# title: Structure of M pro from COVID-19 virus and discovery of its inhibitors
# <cluster=209, paper_id=746>
# title: Multivariate Analyses of Codon Usage of SARS-CoV-2 and other 1 betacoronaviruses
# <cluster=210, paper_id=298>
# title: The role of post-Golgi transport pathways and sorting motifs in the plasmodesmal targeting of the movement protein (MP) of Ourmia melon virus (OuMV)
# <cluster=211, paper_id=572>
# title: Clinical characterization and chest CT findings in laboratory-confirmed COVID-19: a systematic review and meta-analysis
# <cluster=212, paper_id=416>
# title: FilmArray Respiratory Panel Integrated in a field Point Of Care dispositive for the diagnosis of respiratory tract infections in rural areas in Senegal 2 Senegal
# <cluster=213, paper_id=588>
# title: Inflammation induced by influenza virus impairs innate control of human pneumococcal 1 carriage 2
# <cluster=214, paper_id=435>
# title: Forecasting the Wuhan coronavirus (2019-nCoV) epidemics using a simple (simplistic) model
# <cluster=215, paper_id=232>
# title: Altered polarization of PAR-2 signaling during airway epithelial remodeling
# <cluster=216, paper_id=658>
# title: In-vivo targeted tagging of RNA isolates cell specific transcriptional responses to environmental stimuli and identifies liver-to-adipose RNA transfer 2 3
# <cluster=217, paper_id=381>
# title: Imaging Striatal Dopamine Release Using a Non-Genetically Encoded Near-Infrared Fluorescent Catecholamine Nanosensor
# <cluster=218, paper_id=63>
# title: A simple model to assess Wuhan lock-down effect and region efforts during COVID-19 epidemic in China Mainland
# <cluster=219, paper_id=44>
# title: Novel Immunoglobulin Domain Proteins Provide Insights into Evolution and Pathogenesis Mechanisms of SARS-Related Coronaviruses
# <cluster=220, paper_id=684>
# title: Host protein CD63 enhances viral RNA replication by interacting with human astrovirus nonstructural protein nsP1a/4 2
# <cluster=221, paper_id=582>
# title: First evidence of host range expansion in virophages and its potential impact on giant viruses and host cells
# <cluster=222, paper_id=207>
# title: Structure of the SARS-CoV NSP12 polymerase bound to NSP7 and NSP8 co-factors
# <cluster=223, paper_id=547>
# title: The translational landscape of Zika virus during infection of mammalian and 1 insect cells 2 3
# <cluster=224, paper_id=50>
# title: Dissecting genetic and sex-specific host heterogeneity in pathogen transmission 1 potential 2 3 4
# <cluster=225, paper_id=623>
# title: Viral etiology of Acute Respiratory Infections in Hospitalized
# <cluster=226, paper_id=221>
# title: The spatiotemporal estimation of the dynamic risk and the international 1 transmission of 2019 Novel Coronavirus (COVID-19) outbreak: A global 2 perspective 3
# <cluster=227, paper_id=729>
# title: Aberrant pathogenic GM-CSF + T cells and inflammatory CD14 + CD16 + monocytes 1 in severe pulmonary syndrome patients of a new coronavirus 2 3
# <cluster=228, paper_id=634>
# title: TWIRLS, an automated topic-wise inference method based on massive literature, suggests a possible mechanism via ACE2 for the pathological changes in the human host after coronavirus infection
# <cluster=229, paper_id=33>
# title: Molecular Dynamics Simulations Indicate the COVID-19 Mpro Is Not a Viable Target for Small-Molecule Inhibitors Design
# <cluster=230, paper_id=458>
# title:
# <cluster=231, paper_id=210>
# title: A nematode-specific gene underlies bleomycin-response variation in Caenorhabditis elegans 1 2
# <cluster=232, paper_id=728>
# title: Estimation of incubation period distribution of COVID-19 using disease onset forward time: a novel cross-sectional and forward follow-up study
# <cluster=233, paper_id=507>
# title: Epidemiological and clinical features of 2019-nCoV acute respiratory disease cases in Chongqing municipality, China: a retrospective, descriptive, multiple-center study
# <cluster=234, paper_id=253>
# title: Recombinant vector vaccines and within-host evolution 1
# <cluster=235, paper_id=447>
# title: Prodrug defiance reveals logic-based strategies for treating bacterial resistance
# <cluster=236, paper_id=230>
# title: Accelerated viral dynamics in bat cell lines, with implications for zoonotic emergence 1
# <cluster=237, paper_id=9>
# title: ADJUSTED AGE-SPECIFIC CASE FATALITY RATIO DURING THE COVID-19 EPIDEMIC IN HUBEI, CHINA
# <cluster=238, paper_id=514>
# title: Estimation of risk factors for COVID-19 mortality -preliminary results
# <cluster=239, paper_id=426>
# title: Title: Epidemiological and clinical features of 291 cases with coronavirus disease 2019 in areas adjacent to Hubei, China: a double-center observational study
# <cluster=240, paper_id=622>
# title: Title: Antibody responses to SARS-CoV-2 in patients of novel coronavirus disease 2019 Brief Title: Antibody responses in COVID-19 patients Summary Background
# <cluster=241, paper_id=430>
# title: Combination attenuation offers strategy for live-attenuated coronavirus vaccines 1 2
# <cluster=242, paper_id=554>
# title: Neurological Manifestations of Hospitalized Patients with COVID-19 in Wuhan, China: a retrospective case series study
# <cluster=243, paper_id=363>
# title: TALC: Transcription Aware Long Read Correction
# <cluster=244, paper_id=694>
# title: Rapid colorimetric detection of COVID-19 coronavirus using a reverse tran- scriptional loop-mediated isothermal amplification (RT-LAMP) diagnostic plat- form: iLACO
# <cluster=245, paper_id=556>
# title: Quality control implementation for universal characterization of 1 DNA and RNA viruses in clinical respiratory samples using single metagenomic next-generation sequencing workflow
# <cluster=246, paper_id=795>
# title: Effectiveness of airport screening at detecting travellers infected with 2019-nCoV
# <cluster=247, paper_id=288>
# title: TITLE PAGE Clinical features and laboratory inspection of novel coronavirus pneumonia (COVID-19) in Xiangyang, Hubei
# <cluster=248, paper_id=294>
# title: MERS-CoV recombination: implications about the reservoir and potential for adaptation
# <cluster=249, paper_id=149>
# title: Machine learning using intrinsic genomic signatures for rapid classification of novel pathogens: COVID-19 case study
# <cluster=250, paper_id=606>
# title: Awareness of MERS-CoV among Staff Members of Prince Sultan Military Medical City in Riyadh, Saudi Arabia
# <cluster=251, paper_id=255>
# title: Crystal structure of SARS-CoV-2 nucleocapsid protein RNA binding domain 1 reveals potential unique drug targeting sites
# <cluster=252, paper_id=238>
# title: National and Regional Influenza-Like-Illness Forecasts for the USA
# <cluster=253, paper_id=399>
# title:
# <cluster=254, paper_id=23>
# title: A practical generation interval-based approach to inferring the strength of epidemics from their speed Keywords Infectious disease modeling; Generation interval; basic reproductive number 1
# <cluster=255, paper_id=325>
# title: Identification of a Novel Base J Binding Protein Complex Involved in 2 RNA Polymerase II Transcription Termination in Trypanosomes 3 Short Title: PNUTS-PP1 Regulates Transcription Termination in T
# <cluster=256, paper_id=397>
# title: Translational profiling of macrophages infected with Leishmania donovani identifies 2 mTOR-and eIF4A-sensitive immune-related transcripts
# <cluster=257, paper_id=617>
# title: MAD1 domains in the mitotic checkpoint Coordination between discrete Mitotic Arrest Deficient 1 (MAD1) domains is required for efficient mitotic checkpoint signaling
# <cluster=258, paper_id=283>
# title:
# <cluster=259, paper_id=418>
# title: Teicoplanin potently blocks the cell entry of 2019-nCoV
# <cluster=260, paper_id=785>
# title: The lockdown of Hubei Province causing different transmission dynamics of the novel coronavirus (2019-nCoV) in Wuhan and
# <cluster=261, paper_id=722>
# title: Article type: Research Article Title: Under-the-radar dengue virus infections in natural populations of Aedes aegypti mosquitoes Running title: Dengue virus maintenance in mosquito vectors
# <cluster=262, paper_id=308>
# title: Monoclonal antibodies for the S2 subunit of spike of SARS-CoV cross-react with the newly-emerged SARS-CoV-2
# <cluster=263, paper_id=516>
# title: Real-time projections of epidemic transmission and estimation of vaccination impact during an Ebola virus disease outbreak in Northeastern Democratic Republic of Congo
# <cluster=264, paper_id=501>
# title: Potential impact of seasonal forcing on a SARS-CoV-2 pandemic
# <cluster=265, paper_id=239>
# title: Structurally informed evolutionary models improve phylogenetic reconstruction for emerging, seasonal, and pandemic influenza viruses Corresponding Authors 15
# <cluster=266, paper_id=151>
# title: Knowledge and attitudes of Ebola among the general public of Trinidad and Tobago during the 2014-15 West Africa outbreak
# <cluster=267, paper_id=224>
# title: Structure-Guided Mutagenesis Alters Deubiquitinating Activity 2 and Attenuates Pathogenesis of a Murine Coronavirus
# <cluster=268, paper_id=542>
# title: Quantitative Delineation of Herpesviruses in Bats for use in Ecological Studies
# <cluster=269, paper_id=517>
# title: Estimating the Relative Probability of Direct Transmission between Infectious Disease Patients
# <cluster=270, paper_id=112>
# title: Validity of Wrist and Forehead Temperature in Temperature Screening in the General 1 Population During the Outbreak of 2019 Novel Coronavirus: a prospective real-world 2 study 3 4 (Validity of Wrist and Forehead Temperature in Temperature Screening in the General 5 Population During the Outbreak of COVID-19) 6 7
# <cluster=271, paper_id=182>
# title: Machine intelligence design of 2019-nCoV drugs
# <cluster=272, paper_id=563>
# title: Highland of COVID-19 outside Hubei: epidemic characteristics, control and projections of Wenzhou, China
# <cluster=273, paper_id=747>
# title: Title: Anesthetic agents affect urodynamic parameters and anesthetic depth at doses necessary to facilitate preclinical testing in felines
# <cluster=274, paper_id=120>
# title: Assessing the Tendency of 2019-nCoV (COVID-19) Outbreak in China
# <cluster=275, paper_id=649>
# title: The Role of Proton Transport in Gating Current in a Voltage Gated Ion Channel, as Shown by Quantum Calculations
# <cluster=276, paper_id=472>
# title: A data-driven assessment of early travel restrictions related to the spreading of the novel COVID-19 within mainland China
# <cluster=277, paper_id=678>
# title: Multimerization of HIV-1 integrase hinges on conserved SH3-docking platforms
# <cluster=278, paper_id=638>
# title:
# <cluster=279, paper_id=485>
# title: Estimating the Asymptomatic Proportion of 2019 Novel Coronavirus onboard the Princess Cruises Ship, 2020
# <cluster=280, paper_id=231>
# title: Population movement, city closure and spatial transmission of the 2019-nCoV 1 infection in China 2
# <cluster=281, paper_id=36>
# title: An anti-Gn glycoprotein antibody from a convalescent patient potently 2 inhibits the infection of severe fever with thrombocytopenia syndrome virus
# <cluster=282, paper_id=604>
# title: A speed-fidelity trade-off determines the mutation rate and virulence of an RNA virus 2 3 Running Title: Speed-fidelity trade-off 4 5 6 7
# <cluster=283, paper_id=35>
# title: Robitaille et al. 1 DUSP1 regulates apoptosis and cell migration, but not the JIP1-protected cytokine response, during Respiratory Syncytial Virus and Sendai Virus infection
# <cluster=284, paper_id=359>
# title: A quantitative narrative on movement, disease and patch exploitation in nesting agent groups
# <cluster=285, paper_id=567>
# title: Extensive programmed ribosomal frameshifting in human as revealed by a massively parallel reporter assay
# <cluster=286, paper_id=324>
# title: Title: Clinical features and progression of acute respiratory distress syndrome in Nutrition and Safety, Ministry of Education Key Lab of Environment and # Corresponding authors: 1 7 Word count: 2,681 (including Research in context) 2 0
# <cluster=287, paper_id=528>
# title: Transmission and clinical characteristics of coronavirus disease 2019 in 104 outside-Wuhan patients, China
# <cluster=288, paper_id=373>
# title: Antipsychotic behavioral phenotypes in the mouse Collaborative Cross recombinant inbred inter-crosses (RIX)
# <cluster=289, paper_id=697>
# title: A new transmission route for the propagation of the SARS-CoV-2 coronavirus, Danchin, Ng, Turinici A new transmission route for the propagation of the SARS-CoV-2 coronavirus by
# <cluster=290, paper_id=211>
# title: The Evaluation of Sleep Disturbances for Chinese Frontline Medical Workers Under the Outbreak of COVID-19
# <cluster=291, paper_id=736>
# title: Pangolin homology associated with 2019-nCoV
# <cluster=292, paper_id=70>
# title:
# <cluster=293, paper_id=319>
# title: Evolving epidemiology of novel coronavirus diseases 2019 and possible interruption of local transmission outside Hubei Province in China: a descriptive and modeling study
# <cluster=294, paper_id=760>
# title: Clinical characteristics of 82 death cases with COVID-19
# <cluster=295, paper_id=769>
# title: Programmable low-cost DNA-based platform for viral RNA detection
# <cluster=296, paper_id=60>
# title: Original investigation Vicarious traumatization in the general public, members, and non-members of medical teams aiding in COVID-19 control
# <cluster=297, paper_id=742>
# title: Non-uniform refinement: Adaptive regularization improves single particle cryo-EM reconstruction
# <cluster=298, paper_id=652>
# title: Inferring the presence of aflatoxin-producing Aspergillus flavus strains using 3 RNA sequencing and electronic probes as a transcriptomic screening tool 4 5 6
# <cluster=299, paper_id=525>
# title:
# <cluster=300, paper_id=713>
# title: Epidemiological and clinical features of COVID-19 patients with and without pneumonia in Beijing, China
# <cluster=301, paper_id=774>
# title: ARTICLE A case for a reverse-frame coding sequence in a group of positive-sense RNA viruses
# <cluster=302, paper_id=295>
# title: TITLE Containing Emerging Epidemics: a Quantitative Comparison of Quarantine and Symptom Monitoring
# <cluster=303, paper_id=198>
# title: Insights into Cross-species Evolution of Novel Human Coronavirus 2019-nCoV and Defining Immune Determinants for Vaccine Development
# <cluster=304, paper_id=552>
# title: Sequencing of the human IG light chain loci from a hydatidiform mole BAC library reveals locus-specific signatures of genetic diversity
# <cluster=305, paper_id=751>
# title: The role of absolute humidity on transmission rates of the COVID-19 outbreak
# <cluster=306, paper_id=642>
# title: Real-Time Estimation of the Risk of Death from Novel Coronavirus (COVID-19) Infection: Inference Using Exported Cases
# <cluster=307, paper_id=548>
# title: Preliminary epidemiological analysis on children and adolescents with novel coronavirus disease 2019 outside Hubei Province, China: an observational study utilizing crowdsourced data
# <cluster=308, paper_id=739>
# title: Estimation of COVID-19 outbreak size in Italy based on international case exportations
# <cluster=309, paper_id=357>
# title: Processing of the SARS-CoV pp1a/ab nsp7-10 region
# <cluster=310, paper_id=82>
# title: Hypokalemia and Clinical Implications in Patients with Coronavirus Disease 2019 (COVID-19)
# <cluster=311, paper_id=125>
# title: DNA-scaffolded biomaterials enable modular and tunable control of cell-based cancer immunotherapies
# <cluster=312, paper_id=304>
# title: Mechanistic insights into Zika virus NS3 helicase inhibition by Epigallocatechin-3-gallate
# <cluster=313, paper_id=537>
# title: Modeling Epidemics: A Primer and Numerus Software Implementation
# <cluster=314, paper_id=762>
# title: Identification of peptide coatings that enhance diffusive transport of nanoparticles through the tumor microenvironment
# <cluster=315, paper_id=341>
# title: The reproductive number R 0 of COVID-19 based on estimate of a statistical time delay dynamical system
# <cluster=316, paper_id=635>
# title: Transmission of human-associated microbiota along family and social networks 1 2 Authors: 3
# <cluster=317, paper_id=290>
# title: Viral gain-of-function experiments uncover residues under diversifying selection in nature
# <cluster=318, paper_id=443>
# title: Integrative Bioinformatics Analysis Provides Insight into the Molecular Mechanisms of 2019-nCoV
# <cluster=319, paper_id=688>
# title: TITLE: Low basal expression and slow induction of IFITM3 puts immune 1 cells at risk of influenza A infection 2 3 Running head (40 characters): 4 Cells at risk of Influenza A infection 5 6
# <cluster=320, paper_id=614>
# title: Tracking and Predicting COVID-19 Epidemic in China Mainland
# <cluster=321, paper_id=591>
# title: Highly ACE2 Expression in Pancreas May Cause Pancreas Damage After SARS-CoV-2 Infection
# <cluster=322, paper_id=417>
# title: Alpha-ketoamides as broad-spectrum inhibitors of coronavirus and enterovirus replication Structure-based design, synthesis, and activity assessment
# <cluster=323, paper_id=163>
# title: Zika virus outbreak in the Americas: Is Aedes albopictus an overlooked culprit?
# <cluster=324, paper_id=467>
# title: Connectivity analyses of bioenergetic changes in schizophrenia: Identification of novel treatments Running title: Bioenergetic function in schizophrenia
# <cluster=325, paper_id=522>
# title: The effect of human mobility and control measures on the COVID-19 epidemic in China
# <cluster=326, paper_id=437>
# title: AI-aided design of novel targeted covalent inhibitors against SARS-CoV-2
# <cluster=327, paper_id=661>
# title: The influenza A virus endoribonuclease PA-X usurps host mRNA processing machinery to 1 limit host gene expression 2 3
# <cluster=328, paper_id=212>
# title: Rapid Detection of SARS-CoV-2 Using Reverse transcription RT-LAMP method
# <cluster=329, paper_id=171>
# title: Glycosylation of Zika Virus Is Important in Host-Virus Interaction and Pathogenesis 1 USA
# <cluster=330, paper_id=348>
# title: The Viral Protein Corona Directs Viral Pathogenesis and Amyloid Aggregation
# <cluster=331, paper_id=441>
# title: The permeabilized SecY protein-translocation channel can serve as a nonspecific 1 sugar transporter Running Title: Bacterial nonspecific sugar transport 17 18
# <cluster=332, paper_id=423>
# title: Title: Feasibility of controlling 2019-nCoV outbreaks by isolation of cases and contacts
# <cluster=333, paper_id=589>
# title: Real-time monitoring the transmission potential of COVID-19 in Singapore, February 2020
# <cluster=334, paper_id=590>
# title: Prediction of COVID-19 Spreading Profiles in South Korea, Italy and Iran by Data-Driven Coding
# <cluster=335, paper_id=629>
# title: Zika virus infection in Collaborative Cross mice 1 2
# <cluster=336, paper_id=398>
# title: Appealing for Efficient, Well Organized Clinical Trials on COVID-19
# <cluster=337, paper_id=551>
# title: The molecular basis for Pompe disease 3 revealed by the structure of human acid α-glucosidase 4 5
# <cluster=338, paper_id=96>
# title: Serological detection of 2019-nCoV respond to the epidemic: A useful complement to nucleic acid testing
# <cluster=339, paper_id=406>
# title: Glycosyltransferases promote development and prevent promiscuous cell
# <cluster=340, paper_id=271>
# title: Title: Genome Detective Coronavirus Typing Tool for rapid identification and characterization of novel coronavirus genomes Short title: Automated tool for phylogenetic and mutational analysis of coronaviruses genomes
# <cluster=341, paper_id=680>
# title: Clinical characteristics of 36 non-survivors with COVID-19 in Wuhan, China
# <cluster=342, paper_id=317>
# title: Risk Assessment of Novel Coronavirus COVID-19 Outbreaks Outside China
# <cluster=343, paper_id=532>
# ...
# <cluster=696, paper_id=179>
# title: Identification of a Nidovirales Orf1a N7-guanine cap Methyltransferase signature- sequence as a genetic marker of large genome Tobaniviridae Running title: RNA cap N7-guanine Methyltransferase in Tobaniviridae Orf1a
# <cluster=697, paper_id=89>
# title: Enabling large-scale genome editing by reducing DNA nicking
# <cluster=698, paper_id=132>
# title: Original Article
# <cluster=699, paper_id=366>
# title: Title: HOPS-dependent endosomal fusion required for efficient cytosolic delivery of therapeutic peptides and small proteins
# <cluster=700, paper_id=529>
# title: Spread and control of COVID-19 in China and their associations with medical resources 3 4
# <cluster=701, paper_id=483>
# title: Stochastic challenges to interrupting helminth transmission
# <cluster=702, paper_id=351>
# title: Mouse hepatitis virus nsp14 exoribonuclease activity is required for
# <cluster=703, paper_id=757>
# title: Cryo-EM structures of HKU2 and SADS-CoV spike 1 glycoproteins and insights into coronavirus evolution 2 3 4
# <cluster=704, paper_id=332>
# title: Title: The impact of persistent bacterial bronchitis on the pulmonary microbiome of
# <cluster=705, paper_id=690>
# title:
# <cluster=706, paper_id=546>
# title: Analytical sensibility and specificity of two RT-qPCR protocols for SARS-CoV-2 detection performed in an automated workflow
# <cluster=707, paper_id=166>
# title: 68 Consecutive patients assessed for COVID-19 infection; experience from a UK regional infectious disease unit
# <cluster=708, paper_id=22>
# title: A single locus underlies variation in Caenorhabditis elegans chemotherapeutic responses
# <cluster=709, paper_id=536>
# title: Clinical Characteristics of Patients with Severe Pneumonia Caused by the 2019 Novel Coronavirus in Wuhan, China Title: The clinical characteristics of 2019 novel coronavirus severe pneumonia *Corresponding Author
# <cluster=710, paper_id=414>
# title: A novel real-time PCR assay panel for detection of common 1 respiratory pathogens in a convenient, strip-tube array format 2 Running title: Respiratory PCR panel in a strip-tube array format Assistant Professor of Clinical Pathology and Laboratory Medicine Introduction
# <cluster=711, paper_id=196>
# title: An epidemiological forecast model and software assessing interventions on COVID-19 epidemic in China
# <cluster=712, paper_id=218>
# title: Direct RNA nanopore sequencing of full-length coronavirus genomes provides novel insights into structural variants and enables modification analysis
# <cluster=713, paper_id=219>
# title: Modulation of metabolic functions through Cas13d-mediated gene knockdown in liver
# <cluster=714, paper_id=535>
# title: Transmission Dynamics of 2019-nCoV in Malaysia
# <cluster=715, paper_id=702>
# title: DNA segment of African Swine Fever Virus 1 first detected in hard ticks from sheep and bovine
# <cluster=716, paper_id=560>
# title: Establishment of primary transgenic human airway 1 epithelial cell cultures to study respiratory virus - 2 host interactions 3
# <cluster=717, paper_id=601>
# title: G-quadruplex stabilization in the ions and maltose transporters inhibit Salmonella enterica growth and virulence
# <cluster=718, paper_id=734>
# title: Clinical Characteristics of 24 Asymptomatic Infections with COVID-19 Screened among Close Contacts in Nanjing, China School of Public Health (
# <cluster=719, paper_id=500>
# title: Kallikrein 13: a new player in coronaviral infections. 1 2
# <cluster=720, paper_id=204>
# title: Title: Perceptions of the Adult US Population regarding the Novel Coronavirus Outbreak Short title: Perceptions regarding Novel Coronavirus Outbreak
# <cluster=721, paper_id=396>
# title: Estimating the daily trend in the size of the COVID-19 infected population in Wuhan
# <cluster=722, paper_id=245>
# title: A model simulation study on effects of intervention measures in Wuhan COVID-19 epidemic
# <cluster=723, paper_id=214>
# title: Emotional responses and coping strategies of nurses and nursing college students during COVID-19 outbreak
# <cluster=724, paper_id=293>
# title: Assessing Topographic Structural Connectivity of the Human Basal Ganglia and Thalamus
# <cluster=725, paper_id=802>
# title: Analysis of early renal injury in COVID-19 and diagnostic value of multi-index combined detection
# <cluster=726, paper_id=140>
# title: DeepTracer: Predicting Backbone Atomic Structure from High Resolution Cryo-EM Den- sity Maps of Protein Complexes XXXXXXX Received on XXXXX; revised on XXXXX; accepted on XXXXX
# <cluster=727, paper_id=338>
# title: A deep learning algorithm using CT images to screen for Corona Virus Disease (COVID-19)
# <cluster=728, paper_id=131>
# title: Analysis of epidemiological characteristics of coronavirus 2019 infection and preventive measures in Shenzhen China-a heavy population city
# <cluster=729, paper_id=404>
# title: Preliminary estimation of the novel coronavirus disease (COVID-19) cases in Iran: a modelling analysis based on overseas cases and air travel data
# <cluster=730, paper_id=748>
# title: Comparative genomics reveals signature regions used to develop a robust and sensitive multiplex TaqMan real-time qPCR assay to detect the genus Dickeya and Dickeya dianthicola
# <cluster=731, paper_id=4>
# title: Neutrophil-to-Lymphocyte Ratio Predicts Severe Illness Patients with 2019 Novel Coronavirus in the Early Stage
# <cluster=732, paper_id=5>
# title: National Science and Technology Major Project (No. 2017ZX10204401); National Natural Science Foundation of China
# <cluster=733, paper_id=711>
# title: Mutations, Recombination and Insertion in the Evolution of 2019-nCoV
# <cluster=734, paper_id=673>
# title:
# <cluster=735, paper_id=778>
# title: Protective Population Behavior Change in Outbreaks of Emerging Infectious Disease 1 2
# <cluster=736, paper_id=115>
# title: Estimation of the final size of the COVID-19 epidemic
# <cluster=737, paper_id=229>
# title: Clinical Features of COVID-19-Related Liver Damage
# <cluster=738, paper_id=170>
# title: WeChat, a Chinese social media, may early detect the SARS-CoV-2 outbreak in 2019
# <cluster=739, paper_id=124>
# title: Structure and immune recognition of the porcine epidemic diarrhea virus spike protein
# <cluster=740, paper_id=143>
# title: Prediction of the Epidemic of COVID-19 Based on Quarantined Surveillance in China
# <cluster=741, paper_id=102>
# title: Rapid Detection of 2019 Novel Coronavirus SARS-CoV-2 Using a CRISPR-based 1 DETECTR Lateral Flow Assay 2 3
# <cluster=742, paper_id=505>
# title: From Isolation to Coordination: How Can Telemedicine Help Combat the COVID-19 Outbreak?
# <cluster=743, paper_id=208>
# title: Decoupling the effects of nutrition, age and behavioral caste 2 on honey bee physiology and immunity
# <cluster=744, paper_id=621>
# title: Prediction of criticality in patients with severe Covid-19 infection using three clinical features: a machine learning-based prognostic model with clinical data in Wuhan
# <cluster=745, paper_id=240>
# title: Ca 2+ ions promote fusion of Middle East Respiratory Syndrome coronavirus with host cells and increase infectivity
# <cluster=746, paper_id=165>
# title: Epidemic analysis of COVID-19 in China by dynamical modeling
# <cluster=747, paper_id=258>
# title: Using Digital Surveillance Tools for Near Real-Time Mapping of the Risk of International Infectious Disease Spread: Ebola as a Case Study
# <cluster=748, paper_id=100>
# title: Stress-induced phospho-ubiquitin formation causes parkin degradation
# <cluster=749, paper_id=761>
# title: Changes in temperature alter susceptibility to a virus following a Short title: Influence of temperature on virus host shifts 4 5
# <cluster=750, paper_id=327>
# title: TITLE PAGE The SARS-CoV-2 receptor ACE2 expression of maternal-fetal interface and fetal organs by single cell transcriptome study
# <cluster=751, paper_id=18>
# title: Epidemiological and ecological modelling reveal diversity in upper respiratory tract microbial population structures from a cross-sectional community swabbing study Key words Ecology, Epidemiology, Respiratory Infection Running Title Application of epidemiological and ecological modelling to microbial populations Corresponding Author
# <cluster=752, paper_id=445>
# title: Title: Optimizing diagnostic strategy for novel coronavirus pneumonia, a multi-center study in Eastern China Authors (email addresses): Affiliations: Correspondence to
# <cluster=753, paper_id=205>
# title: An Effective CTL Peptide Vaccine for Ebola Zaire Based on Survivors' CD8+ Targeting of a Particular Nucleocapsid Protein Epitope with Potential Implications for COVID-19 Vaccine Design
# <cluster=754, paper_id=720>
# title: In-silico immune cell deconvolution of the airway proteomes of infants with pneumonia reveals a link between reduced airway eosinophils and an increased risk of mortality
# <cluster=755, paper_id=257>
# title: A transmissible RNA pathway in honey bees
# <cluster=756, paper_id=771>
# title: A novel defective recombinant porcine enterovirus G virus carrying a 2 porcine torovirus papain-like cysteine protease gene and a putative anti- 3 apoptosis gene in place of viral structural protein genes 4 5 6 Ryo Imai
# <cluster=757, paper_id=233>
# title: Messenger RNAs transcribed from yeast linear cytoplasmic plasmids possess unconventional 5' and 3' UTRs and suggest a novel mechanism of translation
# <cluster=758, paper_id=162>
# title: Prediction of antiviral drugs against African Swine Fever Viruses based on protein-protein interaction analysis
# <cluster=759, paper_id=250>
# title: A novel bat coronavirus reveals natural insertions at the S1/S2
# <cluster=760, paper_id=602>
# title: Accurate prediction of human essential genes using only nucleotide composition and association information
# <cluster=761, paper_id=727>
# title: A simple laboratory parameter facilitates early identification of COVID-19 patients
# <cluster=762, paper_id=251>
# title: Significance of hydrophobic and charged sequence similarities in sodium-bile acid cotransporter and vitamin D-binding protein macrophage activating factor
# <cluster=763, paper_id=249>
# title: Clinical Characteristics on 25 Discharged Patients with COVID-19 Virus Returning
# <cluster=764, paper_id=268>
# title: Title: Probabilistic reconstruction of measles transmission Authors
# <cluster=765, paper_id=380>
# title: Evidence for RNA editing in the transcriptome of 2019 Novel Coronavirus
# <cluster=766, paper_id=361>
# title: Identification of quercetin from fruits to immediately fight Zika
# <cluster=767, paper_id=410>
# title: Clinical outcomes of 402 patients with COVID-2019 from a single center in Wuhan, China
# <cluster=768, paper_id=496>
# title: Getting to zero quickly in the 2019-nCov epidemic with vaccines or rapid testing
# <cluster=769, paper_id=605>
# title:
# <cluster=770, paper_id=330>
# title: Identification of the relative timing of infectiousness 1 and symptom onset for outbreak control 2
# <cluster=771, paper_id=706>
# title: Replication of MERS and SARS coronaviruses in bat cells offers insights to their 1 ancestral origins 2 3
# <cluster=772, paper_id=465>
# title: IFIT3 and IFIT2/3 promote IFIT1-mediated translation inhibition by enhancing binding to non-self RNA
# <cluster=773, paper_id=427>
# title: Tracking progress towards malaria elimination in China: estimates of 1 reproduction numbers and their spatiotemporal variation 2 3
# <cluster=774, paper_id=235>
# title: DNA breaks-mediated cost reveals RNase HI as a new target for selectively eliminating antibiotic resistance
# <cluster=775, paper_id=161>
# title: BAR scaffolds drive membrane fission by crowding disordered domains
# <cluster=776, paper_id=59>
# title:
# <cluster=777, paper_id=612>
# title: The incubation period of 2019-nCoV from publicly reported confirmed cases: estimation and application
# <cluster=778, paper_id=225>
# title: Title: A mathematical model for estimating the age-specific transmissibility of a novel 3 coronavirus 4 Running title: Age-specific transmissibility of SARS-CoV-2 5
# <cluster=779, paper_id=510>
# title: Estimating the cure rate and case fatality rate of the ongoing epidemic COVID-19
# <cluster=780, paper_id=191>
# title: The within-host viral kinetics of SARS-CoV-2
# <cluster=781, paper_id=664>
# title: Longitudinal characteristics of lymphocyte responses and cytokine profiles in the peripheral blood of SARS-CoV-2 infected patients
# <cluster=782, paper_id=593>
# title: China through a drug-target interaction deep learning model
# <cluster=783, paper_id=438>
# title: Crystal structure of Nsp15 endoribonuclease NendoU from SARS-CoV-2 Running Title: Structure of Nsp15 from SARS-CoV-2
# <cluster=784, paper_id=626>
# title: Evidence for gastrointestinal infection of SARS-CoV-2 1
# <cluster=785, paper_id=134>
# title: The Infectious Bronchitis Virus Coronavirus Envelope Protein Alters Golgi pH to Protect Spike Protein and Promote Release of Infectious Virus
# <cluster=786, paper_id=490>
# title: Vaccination with single plasmid DNA encoding IL-12 and antigens of 2 severe fever with thrombocytopenia syndrome virus elicits complete 3 protection in IFNAR knockout mice Republic of Korea Author summary 57
# <cluster=787, paper_id=202>
# title: Anti-biofilm Activity of Graphene Quantum Dots via Self-Assembly with Bacterial Amyloid Proteins
# <cluster=788, paper_id=701>
# title:
# <cluster=789, paper_id=92>
# title: The impact of regular school closure on seasonal influenza epidemics: a data-driven spatial transmission model for Belgium
# <cluster=790, paper_id=768>
# title: Realtime 2-5A kinetics suggests interferons β and  evade global arrest of translation by RNase L
# <cluster=791, paper_id=183>
# title:
# <cluster=792, paper_id=222>
# title: Single-cell RNA expression profiling of ACE2, the putative receptor of Wuhan 2019-nCov
# <cluster=793, paper_id=735>
# title: Short Title: Mechanism of HCMV gB vaccine-mediated protection 6 7
# <cluster=794, paper_id=703>
# title: TITLE PAGE Title: Machine learning-based CT radiomics model for predicting hospital stay in patients with pneumonia associated with SARS-CoV-2 infection: A multicenter study
# <cluster=795, paper_id=641>
# title: Congruence of location-specific transcriptional programs in intestinal organoids during long-term culture
# <cluster=796, paper_id=226>
# title: Speed and strength of an epidemic intervention
# <cluster=797, paper_id=400>
# title: Risk factors related to hepatic injury in patients with corona virus disease 2019
# <cluster=798, paper_id=167>
# title: Epitope-based peptide vaccine design and target site characterization against novel coronavirus disease caused by SARS-CoV-2
# <cluster=799, paper_id=504>
# title: When will the battle against novel coronavirus end in Wuhan: a SEIR modeling analysis
# <cluster=800, paper_id=732>
# title: Trypsin treatment unlocks barrier for zoonotic coronaviruses infection. Running Title: Trypsin unlocks barrier for zoonotic CoV infection
# <cluster=801, paper_id=27>
# title: Error patterns in connected speech Stark et al Neural organization of speech production: A lesion-based study of error patterns in connected speech
# <cluster=802, paper_id=2>
# title: Classification: Biological Sciences Minor: Microbial Biology Site specific target binding controls RNA cleavage efficiency by the Kaposi's sarcoma-associated herpesvirus endonuclease SOX
# <cluster=803, paper_id=531>
# title: Transferrin binding protein B and Transferrin binding protein A 2 expand the transferrin 1 recognition range of Histophilus somni 2 3 Running title: TbpB and TbpA2 broaden specificity of
# <cluster=804, paper_id=654>
# title: SARS-CoV-2 sensitive to type I interferon pretreatment
# <cluster=805, paper_id=314>
# title: Kinetic Analysis of Bacteriophage Sf6 Binding to Outer Membrane Protein A Using Whole Virions
# <cluster=806, paper_id=1>
# title: Public Exposure to Live Animals, Behavioural Change, and Support in Containment Measures in response to COVID-19 Outbreak: a population-based cross sectional survey in China
# <cluster=807, paper_id=656>
# title: Title 1 Choanoflagellate transfection illuminates their cell biology and the ancestry of animal septins 2 3 Short Title 4 Robust transfection in choanoflagellates 5 6 Authors 7
